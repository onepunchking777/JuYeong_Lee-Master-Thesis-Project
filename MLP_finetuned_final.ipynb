# %%
! pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 23.4 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 22.0 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import StratifiedKFold, train_test_split

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
import matplotlib.pyplot as plt
import optuna
import copy
import random
import os
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pickle
from sklearn.metrics import precision_score, recall_score, precision_recall_curve, roc_curve, f1_score, confusion_matrix, roc_auc_score
pd.set_option('display.max_columns', None)

# %%
# Set global seed for reproducibility
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set the seed and device
seed_everything(42)
epochs = 100
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("[INFO] Device:", device)

# Load CSVs
train_val_df = pd.read_csv('/content/drive/MyDrive/finetuned_train_val_with_structured_final.csv')
test_df = pd.read_csv('/content/drive/MyDrive/finetuned_test_with_structured_final.csv')

# Prepare data (keep on CPU)
X_train_val_np = train_val_df.iloc[:, 0:768].values
y_train_val_np = train_val_df['state_binary'].values

X_test_np = test_df.iloc[:, 0:768].values
y_test_np = test_df['state_binary'].values

# Convert to tensors on CPU
X_train_val = torch.tensor(X_train_val_np, dtype=torch.float32)
y_train_val = torch.tensor(y_train_val_np.reshape(-1, 1), dtype=torch.float32)

X_test = torch.tensor(X_test_np, dtype=torch.float32)
y_test = torch.tensor(y_test_np.reshape(-1, 1), dtype=torch.float32)

print(f"[INFO] Train/Val: {X_train_val.shape[0]} samples x {X_train_val.shape[1]} dims")
print(f"[INFO] Test:      {X_test.shape[0]} samples x {X_test.shape[1]} dims")

# Model definition
def build_model(input_size, trial):
    n_layers = trial.suggest_int("n_layers", 2, 5)
    base_hidden_size = trial.suggest_categorical("hidden_size", [256, 384, 512])
    activation = trial.suggest_categorical("activation", ["ReLU", "LeakyReLU"])
    dropout = trial.suggest_float("dropout", 0.1, 0.4)

    layers = []
    in_features = input_size
    for i in range(n_layers):
        hidden_size = max(int(base_hidden_size // (2 ** i)), 32)
        layers.append(nn.Linear(in_features, hidden_size))

        if activation == "LeakyReLU":
            layers.append(nn.LeakyReLU(0.1))
        else:
            layers.append(getattr(nn, activation)())

        layers.append(nn.Dropout(dropout))
        in_features = hidden_size

    layers.append(nn.Linear(in_features, 1))
    return nn.Sequential(*layers).to(device)

# Training function
loader_kwargs = dict(num_workers=4, pin_memory=True)


def train_model(model, train_loader, val_loader, optimizer, criterion, epochs, patience=10, trial=None, fold_offset=0, delta=1e-4):
    best_val_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    best_f1 = 0.0

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=2
    )

    for epoch in range(epochs):
        model.train()
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            preds = model(xb)
            loss = criterion(preds, yb)
            loss.backward()
            optimizer.step()

        model.eval()
        val_losses, all_preds, all_labels = [], [], []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                preds = model(xb)
                val_losses.append(criterion(preds, yb).item())
                all_preds.append(torch.sigmoid(preds).cpu())
                all_labels.append(yb.cpu())

        avg_val_loss = np.mean(val_losses)
        preds_bin = (torch.cat(all_preds).numpy() > 0.5).astype(int)
        labels_cat = torch.cat(all_labels).numpy()
        val_f1 = f1_score(labels_cat, preds_bin)

        scheduler.step(avg_val_loss)

        if trial:
            trial.report(val_f1, step=fold_offset + epoch)
            if trial.should_prune():
                raise optuna.exceptions.TrialPruned()

        # Early stopping based on validation loss with delta=1e-4
        if avg_val_loss < best_val_loss - delta:  # Only consider improvement > delta
            best_val_loss = avg_val_loss
            best_f1 = val_f1
            best_model_state = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                break

    if best_model_state:
        model.load_state_dict(best_model_state)

    return model, best_f1


# STEP 2: NESTED CV
outer_folds = 5
outer_cv = StratifiedKFold(n_splits=outer_folds, shuffle=True, random_state=42)
outer_results = []

print("\n" + "="*80)
print(" STARTING NESTED CROSS-VALIDATION")
print("="*80)

for outer_fold, (train_idx, val_idx) in enumerate(outer_cv.split(X_train_val.numpy(), y_train_val.numpy())):
    print(f"\n[FOLD {outer_fold + 1}/{outer_folds}] Starting outer fold...")
    X_train_outer = X_train_val[train_idx]
    y_train_outer = y_train_val[train_idx]
    X_val_outer   = X_train_val[val_idx]
    y_val_outer   = y_train_val[val_idx]

    def objective(trial):
        print(f"Starting Trial #{trial.number+1}/50")
        model = build_model(X_train_outer.shape[1], trial)

        optimizer_name  = trial.suggest_categorical("optimizer", ["Adam", "AdamW"])
        lr              = trial.suggest_float("lr", 1e-5, 1e-3, log=True)
        weight_decay    = trial.suggest_float("weight_decay", 1e-6, 1e-3, log=True)
        batch_size      = trial.suggest_categorical("batch_size", [128, 256, 512])



        patience_param = 10
        criterion = nn.BCEWithLogitsLoss()

        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
        f1_scores = []

        for fold_idx, (tr_idx, va_idx) in enumerate(skf.split(X_train_outer.numpy(), y_train_outer.numpy())):
            X_tr, y_tr = X_train_outer[tr_idx], y_train_outer[tr_idx]
            X_va, y_va = X_train_outer[va_idx], y_train_outer[va_idx]

            train_loader = DataLoader(
                TensorDataset(X_tr, y_tr),
                batch_size=batch_size,
                shuffle=True,
                **loader_kwargs
            )
            val_loader = DataLoader(
                TensorDataset(X_va, y_va),
                batch_size=batch_size,
                shuffle=False,
                **loader_kwargs
            )

            model_copy = copy.deepcopy(model)
            optimizer = getattr(optim, optimizer_name)(
                model_copy.parameters(), lr=lr, weight_decay=weight_decay
            )

            # Suppress output during inner CV by passing trial
            trained_model, _ = train_model(
                model_copy, train_loader, val_loader,
                optimizer, criterion, epochs, patience_param,
                trial, fold_idx * epochs
            )

            trained_model.eval()
            with torch.no_grad():
                xb, yb = X_va.to(device), y_va.to(device)
                preds = torch.sigmoid(trained_model(xb)).cpu().numpy()
                preds_bin = (preds > 0.5).astype(int)
                f1_score_fold = f1_score(yb.cpu().numpy(), preds_bin)
                f1_scores.append(f1_score_fold)

        return np.mean(f1_scores)

    print(f"[FOLD {outer_fold + 1}/{outer_folds}] Starting hyperparameter search with Optuna...")

    # Configure Optuna logging to be more concise
    optuna.logging.set_verbosity(optuna.logging.INFO)
    sampler = optuna.samplers.TPESampler(seed=42)
    study = optuna.create_study(
        direction="maximize",
        pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=5)
    )
    study.optimize(objective, n_trials=30)

    best_params = study.best_trial.params
    print(f"\n[FOLD {outer_fold + 1}/{outer_folds}] Best hyperparameters:")
    for param_name, param_value in best_params.items():
        print(f"  - {param_name}: {param_value}")

    # Evaluate on outer validation
    print(f"\n[FOLD {outer_fold + 1}/{outer_folds}] Training model with best hyperparameters...")
    final_model = build_model(X_train_outer.shape[1], optuna.trial.FixedTrial(best_params))
    optimizer  = getattr(optim, best_params['optimizer'])(
        final_model.parameters(),
        lr=best_params['lr'],
        weight_decay=best_params['weight_decay']
    )



    criterion = nn.BCEWithLogitsLoss()

    train_loader = DataLoader(
        TensorDataset(X_train_outer, y_train_outer),
        batch_size=best_params['batch_size'], shuffle=True,
        **loader_kwargs
    )
    val_loader = DataLoader(
        TensorDataset(X_val_outer, y_val_outer),
        batch_size=best_params['batch_size'],
        shuffle=False,
        **loader_kwargs
    )

    final_model, _ = train_model(
        final_model, train_loader, val_loader,
        optimizer, criterion, epochs, patience=10, delta=1e-4
    )

    final_model.eval()
    with torch.no_grad():
        xb, yb = X_val_outer.to(device), y_val_outer.to(device)
        preds = torch.sigmoid(final_model(xb)).cpu().numpy()
        preds_bin = (preds > 0.5).astype(int)
        f1 = f1_score(yb.cpu().numpy(), preds_bin)
        auc = roc_auc_score(yb.cpu().numpy(), preds)
        print(f"\n[FOLD {outer_fold+1}/{outer_folds}] Results: F1={f1:.4f}, AUC={auc:.4f}")

    outer_results.append({
        "fold": outer_fold + 1,
        "f1": f1,
        "auc": auc,
        "params": best_params
    })

print("\n" + "="*80)
print(" NESTED CV COMPLETED")
print("="*80)

# Calculate mean performance across outer folds
mean_f1 = np.mean([r["f1"] for r in outer_results])
mean_auc = np.mean([r["auc"] for r in outer_results])
std_f1 = np.std([r["f1"] for r in outer_results])
std_auc = np.std([r["auc"] for r in outer_results])

print(f"\n[RESULTS] Nested CV Results: ")
print(f"  - Avg F1={mean_f1:.4f} (±{std_f1:.4f})")
print(f"  - Avg AUC={mean_auc:.4f} (±{std_auc:.4f})")

# Print detailed results for each fold
print("\n[DETAILED FOLD RESULTS]")
for res in outer_results:
    print(f"  Fold {res['fold']}: F1={res['f1']:.4f}, AUC={res['auc']:.4f}")

# STEP 3: DETERMINE BEST HYPERPARAMETERS FROM BEST FOLD
print("\n" + "="*80)
print(" DETERMINING BEST HYPERPARAMETERS FROM TOP-PERFORMING FOLD")
print("="*80)

# Find the best-performing fold based on F1 score
best_fold_idx = np.argmax([r["f1"] for r in outer_results])
best_fold_params = outer_results[best_fold_idx]["params"]
best_fold_f1 = outer_results[best_fold_idx]["f1"]
best_fold_auc = outer_results[best_fold_idx]["auc"]

# Use the parameters from the best fold
final_params = best_fold_params.copy()

print(f"\n[BEST FOLD] Fold {best_fold_idx + 1} with F1={best_fold_f1:.4f}, AUC={best_fold_auc:.4f}")
print("\n[FINAL HYPERPARAMETERS]")
for key, value in final_params.items():
    if isinstance(value, float):
        print(f"  - {key}: {value:.6f}")
    else:
        print(f"  - {key}: {value}")

# STEP 3: FINAL TRAIN+VAL EVALUATION WITH METRIC TRACKING
print("\n" + "="*80)
print(" TRAINING FINAL MODEL WITH VALIDATION METRICS TRACKING")
print("="*80)

# Create fixed trial with the best parameters
fixed_trial = optuna.trial.FixedTrial(final_params)

# Initialize the final model
final_model = build_model(X_train_val.shape[1], fixed_trial)
optimizer = getattr(optim, final_params['optimizer'])(
    final_model.parameters(),
    lr=final_params['lr'],
    weight_decay=final_params['weight_decay']
)
criterion = nn.BCEWithLogitsLoss()

# Split train_val data into train and validation sets
X_train_final, X_val_final, y_train_final, y_val_final = train_test_split(
    X_train_val.numpy(), y_train_val.numpy(),
    test_size=0.1, stratify=y_train_val.numpy(), random_state=42
)

# Convert back to tensors
X_train_final = torch.tensor(X_train_final, dtype=torch.float32)
y_train_final = torch.tensor(y_train_final, dtype=torch.float32)
X_val_final = torch.tensor(X_val_final, dtype=torch.float32)
y_val_final = torch.tensor(y_val_final, dtype=torch.float32)

# Create data loaders
train_loader = DataLoader(
    TensorDataset(X_train_final, y_train_final),
    batch_size=final_params['batch_size'],
    shuffle=True,
    **loader_kwargs
)

val_loader = DataLoader(
    TensorDataset(X_val_final, y_val_final),
    batch_size=final_params['batch_size'],
    shuffle=False,
    **loader_kwargs
)


# Metrics tracking function with validation loss as early stopping criterion
def train_with_metrics(model, train_loader, val_loader, optimizer, criterion, epochs, patience=10, delta=1e-4):
    best_val_loss = float('inf')
    best_epoch = 0
    wait = 0
    best_state = copy.deepcopy(model.state_dict())

    # Lists to store metrics
    train_losses = []
    val_losses = []
    train_f1s = []
    val_f1s = []

    # Learning Rate Scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=2
    )

    for epoch in range(epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        train_preds = []
        train_labels = []

        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            outputs = final_model(xb)
            loss = criterion(outputs, yb)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * len(xb)
            train_preds.append(torch.sigmoid(outputs).detach().cpu())
            train_labels.append(yb.detach().cpu())

        # Calculate training metrics
        train_loss /= len(train_loader.dataset)
        train_preds_cat = torch.cat(train_preds).numpy()
        train_labels_cat = torch.cat(train_labels).numpy()
        train_f1 = f1_score(train_labels_cat, (train_preds_cat > 0.5).astype(int))

        # Validation phase
        model.eval()
        val_loss = 0.0
        val_preds = []
        val_labels = []

        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                outputs = final_model(xb)
                loss = criterion(outputs, yb)
                val_loss += loss.item() * len(xb)

                val_preds.append(torch.sigmoid(outputs).cpu())
                val_labels.append(yb.cpu())

        # Calculate validation metrics
        val_loss /= len(val_loader.dataset)
        val_preds_cat = torch.cat(val_preds).numpy()
        val_labels_cat = torch.cat(val_labels).numpy()
        val_f1 = f1_score(val_labels_cat, (val_preds_cat > 0.5).astype(int))

        scheduler.step(val_loss)

        # Store metrics
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_f1s.append(train_f1)
        val_f1s.append(val_f1)

        # Print progress
        print(f"Epoch {epoch+1}/{epochs} - Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, "
              f"Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}")

        # Early stopping check (based on validation loss with delta=1e-4)
        if val_loss < best_val_loss - delta:  # Only save if improvement is greater than delta
            best_val_loss = val_loss
            best_epoch = epoch
            best_state = copy.deepcopy(model.state_dict())
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                print(f"Early stopping triggered! No significant improvement for {patience} epochs.")
                print(f"Best epoch was {best_epoch+1} with validation loss: {best_val_loss:.6f}")
                break

    # Restore best model
    model.load_state_dict(best_state)

    # Plot training curves
    plt.figure(figsize=(15, 10))

    # Loss curves
    plt.subplot(2, 1, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.axvline(x=best_epoch, color='r', linestyle='--',
                label=f'Best Epoch ({best_epoch+1})')
    plt.title('Loss Curves')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # F1 score curves
    plt.subplot(2, 1, 2)
    plt.plot(train_f1s, label='Training F1')
    plt.plot(val_f1s, label='Validation F1')
    plt.axvline(x=best_epoch, color='r', linestyle='--',
                label=f'Best Epoch ({best_epoch+1})')
    plt.title('F1 Score Curves')
    plt.xlabel('Epoch')
    plt.ylabel('F1 Score')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

    # Return model and metrics
    return model, {
        'best_epoch': best_epoch,
        'best_val_loss': best_val_loss,
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_f1s': train_f1s,
        'val_f1s': val_f1s
    }

# Train with metrics tracking
print("\n[TRACKING] Training final model with metrics tracking...")
final_model, metrics = train_with_metrics(
    final_model, train_loader, val_loader,
    optimizer, criterion, epochs=epochs, patience=10, delta=1e-4
)

# Print results
print(f"\n[RESULTS] Best validation loss: {metrics['best_val_loss']:.4f}, F1: {metrics['val_f1s'][metrics['best_epoch']]:.4f} at epoch {metrics['best_epoch']+1}")

# Calculate and display metrics at best epoch
best_epoch = metrics['best_epoch']
print(f"\n[METRICS] At best epoch {best_epoch+1}:")
print(f"  - Training Loss: {metrics['train_losses'][best_epoch]:.4f}")
print(f"  - Validation Loss: {metrics['val_losses'][best_epoch]:.4f}")
print(f"  - Training F1: {metrics['train_f1s'][best_epoch]:.4f}")
print(f"  - Validation F1: {metrics['val_f1s'][best_epoch]:.4f}")

# Apply smoothing to the curves
from scipy.signal import savgol_filter

# Function to apply smoothing
def apply_smoothing(data, window_length=5, polyorder=2):
    if len(data) <= window_length:
        return data  # Not enough data points for smoothing

    # Ensure window_length is odd
    if window_length % 2 == 0:
        window_length += 1

    return savgol_filter(data, window_length, polyorder)

# Plot smoothed curves
plt.figure(figsize=(15, 10))

# Loss curves (smoothed)
plt.subplot(2, 1, 1)
train_losses = metrics['train_losses']
val_losses = metrics['val_losses']

if len(train_losses) >= 5:  # Only smooth if we have enough points
    train_losses_smooth = apply_smoothing(train_losses)
    val_losses_smooth = apply_smoothing(val_losses)

    plt.plot(train_losses, 'b-', alpha=0.3, label='Training Loss (Raw)')
    plt.plot(val_losses, 'orange', alpha=0.3, label='Validation Loss (Raw)')
    plt.plot(train_losses_smooth, 'b-', linewidth=2, label='Training Loss (Smoothed)')
    plt.plot(val_losses_smooth, 'orange', linewidth=2, label='Validation Loss (Smoothed)')
else:
    plt.plot(train_losses, 'b-', label='Training Loss')
    plt.plot(val_losses, 'orange', label='Validation Loss')

plt.axvline(x=best_epoch, color='r', linestyle='--', label=f'Best Epoch ({best_epoch+1})')
plt.title('Loss Curves (Smoothed)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# F1 score curves (smoothed)
plt.subplot(2, 1, 2)
train_f1s = metrics['train_f1s']
val_f1s = metrics['val_f1s']

if len(train_f1s) >= 5:  # Only smooth if we have enough points
    train_f1s_smooth = apply_smoothing(train_f1s)
    val_f1s_smooth = apply_smoothing(val_f1s)

    plt.plot(train_f1s, 'b-', alpha=0.3, label='Training F1 (Raw)')
    plt.plot(val_f1s, 'orange', alpha=0.3, label='Validation F1 (Raw)')
    plt.plot(train_f1s_smooth, 'b-', linewidth=2, label='Training F1 (Smoothed)')
    plt.plot(val_f1s_smooth, 'orange', linewidth=2, label='Validation F1 (Smoothed)')
else:
    plt.plot(train_f1s, 'b-', label='Training F1')
    plt.plot(val_f1s, 'orange', label='Validation F1')

plt.axvline(x=best_epoch, color='r', linestyle='--', label=f'Best Epoch ({best_epoch+1})')
plt.title('F1 Score Curves (Smoothed)')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

print("\n[CONCLUSION] Based on the validation F1 score curves, the optimal number of epochs")
print(f"             for training the final model is: {best_epoch+1}")
# Out:
# [INFO] Device: cuda
# [I 2025-05-17 12:42:14,547] A new study created in memory with name: no-name-00481bb7-5f11-432c-80d0-0170ca2a65b2
# [INFO] Train/Val: 146089 samples x 768 dims
# [INFO] Test:      16233 samples x 768 dims
#
# ================================================================================
#  STARTING NESTED CROSS-VALIDATION
# ================================================================================
#
# [FOLD 1/5] Starting outer fold...
# [FOLD 1/5] Starting hyperparameter search with Optuna...
# Starting Trial #1/50
# [I 2025-05-17 12:44:09,709] Trial 0 finished with value: 0.8596447379122472 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.18505225107198273, 'optimizer': 'Adam', 'lr': 3.1766815052436886e-05, 'weight_decay': 0.00013673275106462532, 'batch_size': 512}. Best is trial 0 with value: 0.8596447379122472.
# Starting Trial #2/50
# [I 2025-05-17 12:45:33,340] Trial 1 finished with value: 0.8591976452434564 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.2696086280073847, 'optimizer': 'Adam', 'lr': 3.1823485668540056e-05, 'weight_decay': 1.60021031270847e-05, 'batch_size': 512}. Best is trial 0 with value: 0.8596447379122472.
# Starting Trial #3/50
# [I 2025-05-17 12:49:36,701] Trial 2 finished with value: 0.8594255759921184 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.1313119147280993, 'optimizer': 'Adam', 'lr': 1.6631586777906927e-05, 'weight_decay': 7.618900639436462e-06, 'batch_size': 128}. Best is trial 0 with value: 0.8596447379122472.
# Starting Trial #4/50
# [I 2025-05-17 12:52:48,891] Trial 3 finished with value: 0.8593247811669903 and parameters: {'n_layers': 5, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.3002753771690305, 'optimizer': 'AdamW', 'lr': 2.0736342133943924e-05, 'weight_decay': 1.5741323705488392e-06, 'batch_size': 256}. Best is trial 0 with value: 0.8596447379122472.
# Starting Trial #5/50
# [I 2025-05-17 12:54:06,805] Trial 4 finished with value: 0.8587234114227281 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.3486276866979604, 'optimizer': 'AdamW', 'lr': 0.0006081305947193272, 'weight_decay': 8.615003799978833e-05, 'batch_size': 256}. Best is trial 0 with value: 0.8596447379122472.
# Starting Trial #6/50
# [I 2025-05-17 12:55:26,526] Trial 5 finished with value: 0.8585536421346905 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.2930141818164429, 'optimizer': 'AdamW', 'lr': 0.0001774767274320337, 'weight_decay': 1.047933348814704e-06, 'batch_size': 256}. Best is trial 0 with value: 0.8596447379122472.
# Starting Trial #7/50
# [I 2025-05-17 12:55:43,673] Trial 6 pruned.
# Starting Trial #8/50
# [I 2025-05-17 12:56:07,514] Trial 7 pruned.
# Starting Trial #9/50
# [I 2025-05-17 12:57:05,876] Trial 8 finished with value: 0.860378493025206 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.32592699631815053, 'optimizer': 'AdamW', 'lr': 0.0003299192302462676, 'weight_decay': 0.00020582330316093862, 'batch_size': 512}. Best is trial 8 with value: 0.860378493025206.
# Starting Trial #10/50
# [I 2025-05-17 12:58:04,564] Trial 9 finished with value: 0.8591664543076817 and parameters: {'n_layers': 5, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.3057068728788689, 'optimizer': 'AdamW', 'lr': 0.0005628340669779726, 'weight_decay': 5.445535211349155e-06, 'batch_size': 512}. Best is trial 8 with value: 0.860378493025206.
# Starting Trial #11/50
# [I 2025-05-17 12:59:02,305] Trial 10 finished with value: 0.8599954011023021 and parameters: {'n_layers': 2, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.3908744509089308, 'optimizer': 'AdamW', 'lr': 0.00014909669243022867, 'weight_decay': 0.0009151951053287553, 'batch_size': 512}. Best is trial 8 with value: 0.860378493025206.
# Starting Trial #12/50
# [I 2025-05-17 13:00:20,267] Trial 11 finished with value: 0.8602598076216387 and parameters: {'n_layers': 2, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.39059452631343416, 'optimizer': 'AdamW', 'lr': 0.00017291744879675307, 'weight_decay': 0.0008428677781820532, 'batch_size': 512}. Best is trial 8 with value: 0.860378493025206.
# Starting Trial #13/50
# [I 2025-05-17 13:01:25,214] Trial 12 finished with value: 0.8608793352964037 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.34242706983728455, 'optimizer': 'AdamW', 'lr': 0.0003156573795348231, 'weight_decay': 0.000956387026941356, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #14/50
# [I 2025-05-17 13:02:26,375] Trial 13 finished with value: 0.8606684719609018 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.3396326985790253, 'optimizer': 'AdamW', 'lr': 0.0003204178509404089, 'weight_decay': 0.00030247522471362967, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #15/50
# [I 2025-05-17 13:03:19,281] Trial 14 finished with value: 0.8591124459556544 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.24514434633422338, 'optimizer': 'AdamW', 'lr': 0.0009419928169557263, 'weight_decay': 0.0004074571867877121, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #16/50
# [I 2025-05-17 13:04:38,866] Trial 15 finished with value: 0.8598992570331004 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.34444371296796467, 'optimizer': 'AdamW', 'lr': 8.745633706886374e-05, 'weight_decay': 6.493247368338152e-05, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #17/50
# [I 2025-05-17 13:05:31,287] Trial 16 finished with value: 0.8603910345466309 and parameters: {'n_layers': 3, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.2393692128793438, 'optimizer': 'AdamW', 'lr': 0.00032909043460162485, 'weight_decay': 0.0003108539777147499, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #18/50
# [I 2025-05-17 13:06:56,656] Trial 17 finished with value: 0.8596130032454244 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.3676928131216253, 'optimizer': 'AdamW', 'lr': 8.193373258813358e-05, 'weight_decay': 0.0004738400851110307, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #19/50
# [I 2025-05-17 13:08:53,579] Trial 18 finished with value: 0.8596918295911645 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.10603485100574905, 'optimizer': 'AdamW', 'lr': 0.00034320343871022785, 'weight_decay': 7.212832861373423e-05, 'batch_size': 128}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #20/50
# [I 2025-05-17 13:10:41,885] Trial 19 finished with value: 0.8597815916020309 and parameters: {'n_layers': 3, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.27406695824481275, 'optimizer': 'AdamW', 'lr': 5.346004362404545e-05, 'weight_decay': 3.4205646547323663e-05, 'batch_size': 256}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #21/50
# [I 2025-05-17 13:11:47,441] Trial 20 finished with value: 0.8601683296549704 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.32289832621727466, 'optimizer': 'AdamW', 'lr': 0.00025771593052403347, 'weight_decay': 0.00018840824148574174, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #22/50
# [I 2025-05-17 13:13:00,577] Trial 21 finished with value: 0.8584865426692336 and parameters: {'n_layers': 3, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.23568209922813987, 'optimizer': 'AdamW', 'lr': 0.0004863334685445336, 'weight_decay': 0.00039449768964200355, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #23/50
# [I 2025-05-17 13:14:04,573] Trial 22 finished with value: 0.8591250210259029 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.179787427424377, 'optimizer': 'AdamW', 'lr': 0.0009229783026021657, 'weight_decay': 0.0003180772387289736, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #24/50
# [I 2025-05-17 13:15:01,477] Trial 23 finished with value: 0.8586393777929783 and parameters: {'n_layers': 3, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.2159964728396494, 'optimizer': 'AdamW', 'lr': 0.00025517746165468804, 'weight_decay': 0.0009165515945752699, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #25/50
# [I 2025-05-17 13:15:53,347] Trial 24 finished with value: 0.860081926656382 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.27536031155871094, 'optimizer': 'AdamW', 'lr': 0.0004094454923940556, 'weight_decay': 0.0005732194765734354, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #26/50
# [I 2025-05-17 13:16:03,304] Trial 25 pruned.
# Starting Trial #27/50
# [I 2025-05-17 13:17:09,727] Trial 26 finished with value: 0.8587143718880093 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.1794454286033239, 'optimizer': 'Adam', 'lr': 0.00023363008789011622, 'weight_decay': 3.769580741448655e-05, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #28/50
# [I 2025-05-17 13:18:05,071] Trial 27 finished with value: 0.8589593087109949 and parameters: {'n_layers': 3, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.22055234166132903, 'optimizer': 'AdamW', 'lr': 0.0006732700453197256, 'weight_decay': 0.00010150084963388915, 'batch_size': 512}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #29/50
# [I 2025-05-17 13:20:14,657] Trial 28 finished with value: 0.8593395931158329 and parameters: {'n_layers': 2, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.2573825550393008, 'optimizer': 'AdamW', 'lr': 6.18962551320443e-05, 'weight_decay': 0.000292543228362418, 'batch_size': 128}. Best is trial 12 with value: 0.8608793352964037.
# Starting Trial #30/50
# [I 2025-05-17 13:20:24,989] Trial 29 pruned.
# [FOLD 1/5] Best hyperparameters:
#   - n_layers: 4
#   - hidden_size: 384
#   - activation: ReLU
#   - dropout: 0.34242706983728455
#   - optimizer: AdamW
#   - lr: 0.0003156573795348231
#   - weight_decay: 0.000956387026941356
#   - batch_size: 512
#
# [FOLD 1/5] Training model with best hyperparameters...
# [I 2025-05-17 13:20:50,135] A new study created in memory with name: no-name-dcbc6865-e9c9-4908-ae2c-2a90c8b45923
# [FOLD 1/5] Results: F1=0.8622, AUC=0.8963
#
# [FOLD 2/5] Starting outer fold...
# [FOLD 2/5] Starting hyperparameter search with Optuna...
# Starting Trial #1/50
# [I 2025-05-17 13:24:54,834] Trial 0 finished with value: 0.8600066887120895 and parameters: {'n_layers': 2, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.2490646753118635, 'optimizer': 'Adam', 'lr': 1.0458205886013086e-05, 'weight_decay': 3.03648248686002e-06, 'batch_size': 128}. Best is trial 0 with value: 0.8600066887120895.
# Starting Trial #2/50
# [I 2025-05-17 13:27:48,311] Trial 1 finished with value: 0.8604264201832214 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.38553895449448816, 'optimizer': 'AdamW', 'lr': 4.1753387991408876e-05, 'weight_decay': 4.999633152557713e-05, 'batch_size': 128}. Best is trial 1 with value: 0.8604264201832214.
# Starting Trial #3/50
# [I 2025-05-17 13:32:34,316] Trial 2 finished with value: 0.8596658590009482 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.36358557810819336, 'optimizer': 'AdamW', 'lr': 1.0727617725489334e-05, 'weight_decay': 0.0008168529549321196, 'batch_size': 256}. Best is trial 1 with value: 0.8604264201832214.
# Starting Trial #4/50
# [I 2025-05-17 13:34:49,182] Trial 3 finished with value: 0.8593908909552138 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.14792654723743165, 'optimizer': 'Adam', 'lr': 0.0001850401445524405, 'weight_decay': 3.0298026205917035e-05, 'batch_size': 128}. Best is trial 1 with value: 0.8604264201832214.
# Starting Trial #5/50
# [I 2025-05-17 13:40:27,528] Trial 4 finished with value: 0.860139696829914 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.15502209461575525, 'optimizer': 'AdamW', 'lr': 1.032412577398228e-05, 'weight_decay': 0.0002943773483110684, 'batch_size': 128}. Best is trial 1 with value: 0.8604264201832214.
# Starting Trial #6/50
# [I 2025-05-17 13:42:21,140] Trial 5 finished with value: 0.8600753746382871 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.3268405166202282, 'optimizer': 'AdamW', 'lr': 7.310891801017555e-05, 'weight_decay': 1.3498623581161289e-06, 'batch_size': 256}. Best is trial 1 with value: 0.8604264201832214.
# Starting Trial #7/50
# [I 2025-05-17 13:43:24,489] Trial 6 finished with value: 0.8604890391271786 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.26571956790815954, 'optimizer': 'Adam', 'lr': 0.00022994834308978407, 'weight_decay': 9.433204489100918e-05, 'batch_size': 512}. Best is trial 6 with value: 0.8604890391271786.
# Starting Trial #8/50
# [I 2025-05-17 13:46:39,511] Trial 7 finished with value: 0.861003032871547 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.11732274424324338, 'optimizer': 'Adam', 'lr': 0.0003901325779177271, 'weight_decay': 0.0008742872030270754, 'batch_size': 128}. Best is trial 7 with value: 0.861003032871547.
# Starting Trial #9/50
# [I 2025-05-17 13:48:09,782] Trial 8 finished with value: 0.8604983200591758 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.21678057975566925, 'optimizer': 'AdamW', 'lr': 7.275048230159126e-05, 'weight_decay': 2.444039315300628e-06, 'batch_size': 512}. Best is trial 7 with value: 0.861003032871547.
# Starting Trial #10/50
# [I 2025-05-17 13:50:53,034] Trial 9 finished with value: 0.8598036103222196 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.19136925558727247, 'optimizer': 'Adam', 'lr': 2.1551922282981964e-05, 'weight_decay': 1.969783262912543e-05, 'batch_size': 128}. Best is trial 7 with value: 0.861003032871547.
# Starting Trial #11/50
# [I 2025-05-17 13:53:25,431] Trial 10 finished with value: 0.8609026528693106 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.10822371420631077, 'optimizer': 'Adam', 'lr': 0.0008999684116972564, 'weight_decay': 0.0008905620445079756, 'batch_size': 256}. Best is trial 7 with value: 0.861003032871547.
# Starting Trial #12/50
# [I 2025-05-17 13:55:12,328] Trial 11 finished with value: 0.8593250250165325 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.10449812526878585, 'optimizer': 'Adam', 'lr': 0.00087733157855606, 'weight_decay': 0.0005422351097625723, 'batch_size': 256}. Best is trial 7 with value: 0.861003032871547.
# Starting Trial #13/50
# [I 2025-05-17 13:57:18,527] Trial 12 finished with value: 0.8611095445025962 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.10702203784291481, 'optimizer': 'Adam', 'lr': 0.0008797552729613046, 'weight_decay': 0.0001820972229045534, 'batch_size': 256}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #14/50
# [I 2025-05-17 13:58:59,616] Trial 13 finished with value: 0.8600855942571956 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.1480650066853525, 'optimizer': 'Adam', 'lr': 0.0004120775450974513, 'weight_decay': 0.00017712901715825763, 'batch_size': 256}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #15/50
# [I 2025-05-17 14:00:04,842] Trial 14 finished with value: 0.8595679530147633 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.10321254337693613, 'optimizer': 'Adam', 'lr': 0.0003775704581553718, 'weight_decay': 0.0002496551023980922, 'batch_size': 512}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #16/50
# [I 2025-05-17 14:02:33,724] Trial 15 finished with value: 0.8599600869764558 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.18646545860593497, 'optimizer': 'Adam', 'lr': 0.0004997097267348785, 'weight_decay': 1.4779144102749094e-05, 'batch_size': 128}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #17/50
# [I 2025-05-17 14:04:32,314] Trial 16 finished with value: 0.8600573284951021 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.2947453776996062, 'optimizer': 'Adam', 'lr': 0.00018642497098628275, 'weight_decay': 0.0001052569202086993, 'batch_size': 256}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #18/50
# [I 2025-05-17 14:06:15,738] Trial 17 finished with value: 0.8606774761253981 and parameters: {'n_layers': 3, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.1402361240464592, 'optimizer': 'Adam', 'lr': 0.0005607684484234447, 'weight_decay': 0.00038676151582038706, 'batch_size': 256}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #19/50
# [I 2025-05-17 14:08:49,577] Trial 18 finished with value: 0.8584380392086706 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.19258119383738714, 'optimizer': 'Adam', 'lr': 0.0002980852887545037, 'weight_decay': 7.684348366095833e-05, 'batch_size': 128}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #20/50
# [I 2025-05-17 14:10:17,074] Trial 19 finished with value: 0.8603609366392252 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.22977883955500544, 'optimizer': 'Adam', 'lr': 0.00012711153820069108, 'weight_decay': 7.1793815162408815e-06, 'batch_size': 512}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #21/50
# [I 2025-05-17 14:11:47,510] Trial 20 finished with value: 0.8603907658308788 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.1291051683262703, 'optimizer': 'Adam', 'lr': 0.0006839428173936735, 'weight_decay': 0.00018165372051313312, 'batch_size': 256}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #22/50
# [I 2025-05-17 14:13:46,310] Trial 21 finished with value: 0.8596627196170514 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.1014112108219851, 'optimizer': 'Adam', 'lr': 0.0009731547552729281, 'weight_decay': 0.0009507718822633856, 'batch_size': 256}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #23/50
# [I 2025-05-17 14:15:41,826] Trial 22 finished with value: 0.8601467027830435 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.1711429621692376, 'optimizer': 'Adam', 'lr': 0.0006651805689096396, 'weight_decay': 0.0005089731808232493, 'batch_size': 256}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #24/50
# [I 2025-05-17 14:18:07,395] Trial 23 finished with value: 0.8606243606954719 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.12502332985822218, 'optimizer': 'Adam', 'lr': 0.0009386656745208515, 'weight_decay': 0.0008347646883242884, 'batch_size': 256}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #25/50
# [I 2025-05-17 14:20:29,554] Trial 24 finished with value: 0.860744553513359 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.12120662182982907, 'optimizer': 'Adam', 'lr': 0.00031256844544607287, 'weight_decay': 0.0004801623762312877, 'batch_size': 256}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #26/50
# [I 2025-05-17 14:23:14,422] Trial 25 finished with value: 0.8592784265767676 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.16368516564753155, 'optimizer': 'Adam', 'lr': 0.0006295049737859992, 'weight_decay': 0.0001593715009760783, 'batch_size': 128}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #27/50
# [I 2025-05-17 14:24:32,313] Trial 26 pruned.
# Starting Trial #28/50
# [I 2025-05-17 14:26:53,431] Trial 27 finished with value: 0.8603378616090932 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.17331141960679222, 'optimizer': 'Adam', 'lr': 0.000758152210570537, 'weight_decay': 0.0009513866043980311, 'batch_size': 256}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #29/50
# [I 2025-05-17 14:28:00,885] Trial 28 finished with value: 0.8596636745320386 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.21990431573811747, 'optimizer': 'Adam', 'lr': 0.00029396197996802445, 'weight_decay': 5.257002790398515e-05, 'batch_size': 512}. Best is trial 12 with value: 0.8611095445025962.
# Starting Trial #30/50
# [I 2025-05-17 14:30:39,097] Trial 29 finished with value: 0.8607046678115641 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.2625878327455493, 'optimizer': 'Adam', 'lr': 0.00010831486284584507, 'weight_decay': 0.0005104886350489352, 'batch_size': 128}. Best is trial 12 with value: 0.8611095445025962.
# [FOLD 2/5] Best hyperparameters:
#   - n_layers: 5
#   - hidden_size: 384
#   - activation: LeakyReLU
#   - dropout: 0.10702203784291481
#   - optimizer: Adam
#   - lr: 0.0008797552729613046
#   - weight_decay: 0.0001820972229045534
#   - batch_size: 256
#
# [FOLD 2/5] Training model with best hyperparameters...
# [I 2025-05-17 14:31:35,976] A new study created in memory with name: no-name-6a34e157-70fa-4d3a-a470-b2854ed7ce1e
# [FOLD 2/5] Results: F1=0.8600, AUC=0.8967
#
# [FOLD 3/5] Starting outer fold...
# [FOLD 3/5] Starting hyperparameter search with Optuna...
# Starting Trial #1/50
# [I 2025-05-17 14:34:04,042] Trial 0 finished with value: 0.8588427492485272 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.2083185891705757, 'optimizer': 'Adam', 'lr': 0.00011680791987296009, 'weight_decay': 1.6861983322099978e-05, 'batch_size': 128}. Best is trial 0 with value: 0.8588427492485272.
# Starting Trial #2/50
# [I 2025-05-17 14:35:39,354] Trial 1 finished with value: 0.8599507157458511 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.22211111397548944, 'optimizer': 'Adam', 'lr': 0.00010725671604800994, 'weight_decay': 2.1645654029272414e-05, 'batch_size': 256}. Best is trial 1 with value: 0.8599507157458511.
# Starting Trial #3/50
# [I 2025-05-17 14:37:02,204] Trial 2 finished with value: 0.8607157373656277 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.12013674701480603, 'optimizer': 'Adam', 'lr': 0.000657658774427678, 'weight_decay': 1.31904984696384e-05, 'batch_size': 256}. Best is trial 2 with value: 0.8607157373656277.
# Starting Trial #4/50
# [I 2025-05-17 14:41:29,654] Trial 3 finished with value: 0.8588603711372622 and parameters: {'n_layers': 5, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.37728409012174546, 'optimizer': 'AdamW', 'lr': 1.0972537934745979e-05, 'weight_decay': 2.0999961650126615e-05, 'batch_size': 256}. Best is trial 2 with value: 0.8607157373656277.
# Starting Trial #5/50
# [I 2025-05-17 14:42:54,608] Trial 4 finished with value: 0.8593543446652362 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.11755961328084101, 'optimizer': 'AdamW', 'lr': 0.00038985199744566673, 'weight_decay': 7.535267768406997e-06, 'batch_size': 256}. Best is trial 2 with value: 0.8607157373656277.
# Starting Trial #6/50
# [I 2025-05-17 14:43:12,103] Trial 5 pruned.
# Starting Trial #7/50
# [I 2025-05-17 14:44:21,486] Trial 6 pruned.
# Starting Trial #8/50
# [I 2025-05-17 14:45:15,425] Trial 7 pruned.
# Starting Trial #9/50
# [I 2025-05-17 14:46:29,505] Trial 8 pruned.
# Starting Trial #10/50
# [I 2025-05-17 14:47:29,545] Trial 9 pruned.
# Starting Trial #11/50
# [I 2025-05-17 14:48:03,244] Trial 10 pruned.
# Starting Trial #12/50
# [I 2025-05-17 14:48:38,836] Trial 11 pruned.
# Starting Trial #13/50
# [I 2025-05-17 14:49:10,533] Trial 12 pruned.
# Starting Trial #14/50
# [I 2025-05-17 14:51:08,902] Trial 13 finished with value: 0.8598455354566132 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.3146231310444998, 'optimizer': 'Adam', 'lr': 0.000826377908273694, 'weight_decay': 3.3437400043911495e-05, 'batch_size': 512}. Best is trial 2 with value: 0.8607157373656277.
# Starting Trial #15/50
# [I 2025-05-17 14:51:46,464] Trial 14 pruned.
# Starting Trial #16/50
# [I 2025-05-17 14:52:21,864] Trial 15 pruned.
# Starting Trial #17/50
# [I 2025-05-17 14:52:57,210] Trial 16 pruned.
# Starting Trial #18/50
# [I 2025-05-17 14:53:30,771] Trial 17 pruned.
# Starting Trial #19/50
# [I 2025-05-17 14:54:14,622] Trial 18 pruned.
# Starting Trial #20/50
# [I 2025-05-17 14:55:06,481] Trial 19 pruned.
# Starting Trial #21/50
# [I 2025-05-17 14:55:31,540] Trial 20 pruned.
# Starting Trial #22/50
# [I 2025-05-17 14:56:42,361] Trial 21 pruned.
# Starting Trial #23/50
# [I 2025-05-17 14:56:53,045] Trial 22 pruned.
# Starting Trial #24/50
# [I 2025-05-17 14:57:22,618] Trial 23 pruned.
# Starting Trial #25/50
# [I 2025-05-17 14:57:49,759] Trial 24 pruned.
# Starting Trial #26/50
# [I 2025-05-17 14:59:20,765] Trial 25 pruned.
# Starting Trial #27/50
# [I 2025-05-17 14:59:46,100] Trial 26 pruned.
# Starting Trial #28/50
# [I 2025-05-17 14:59:59,552] Trial 27 pruned.
# Starting Trial #29/50
# [I 2025-05-17 15:00:42,128] Trial 28 pruned.
# Starting Trial #30/50
# [I 2025-05-17 15:01:09,793] Trial 29 pruned.
# [FOLD 3/5] Best hyperparameters:
#   - n_layers: 3
#   - hidden_size: 256
#   - activation: ReLU
#   - dropout: 0.12013674701480603
#   - optimizer: Adam
#   - lr: 0.000657658774427678
#   - weight_decay: 1.31904984696384e-05
#   - batch_size: 256
#
# [FOLD 3/5] Training model with best hyperparameters...
# [I 2025-05-17 15:01:49,539] A new study created in memory with name: no-name-5464e7e5-55e3-4f62-9520-565b9e1e8d49
# [FOLD 3/5] Results: F1=0.8591, AUC=0.8938
#
# [FOLD 4/5] Starting outer fold...
# [FOLD 4/5] Starting hyperparameter search with Optuna...
# Starting Trial #1/50
# [I 2025-05-17 15:04:33,169] Trial 0 finished with value: 0.8612239440338515 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.3320340702321666, 'optimizer': 'Adam', 'lr': 0.000420042405032095, 'weight_decay': 8.384119791490705e-05, 'batch_size': 128}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #2/50
# [I 2025-05-17 15:07:21,929] Trial 1 finished with value: 0.8591252490849722 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.1012719425101445, 'optimizer': 'Adam', 'lr': 0.000628265853611849, 'weight_decay': 5.948977866055321e-05, 'batch_size': 128}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #3/50
# [I 2025-05-17 15:08:54,466] Trial 2 finished with value: 0.8604949389904365 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.3539190004110945, 'optimizer': 'Adam', 'lr': 0.00024747754596255345, 'weight_decay': 1.3736792571998742e-05, 'batch_size': 512}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #4/50
# [I 2025-05-17 15:10:13,451] Trial 3 finished with value: 0.859213154176015 and parameters: {'n_layers': 3, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.30089770101869384, 'optimizer': 'Adam', 'lr': 0.0005083435491055067, 'weight_decay': 2.8732699633997103e-06, 'batch_size': 512}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #5/50
# [I 2025-05-17 15:12:36,552] Trial 4 finished with value: 0.859459971754419 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.2236596135527154, 'optimizer': 'Adam', 'lr': 0.00023299377346304814, 'weight_decay': 0.0008477240222368504, 'batch_size': 256}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #6/50
# [I 2025-05-17 15:12:46,882] Trial 5 pruned.
# Starting Trial #7/50
# [I 2025-05-17 15:14:11,468] Trial 6 finished with value: 0.8604149862305356 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.13670454383427139, 'optimizer': 'Adam', 'lr': 0.0004851798307474061, 'weight_decay': 3.397198037791093e-06, 'batch_size': 512}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #8/50
# [I 2025-05-17 15:16:37,268] Trial 7 finished with value: 0.8578429808936522 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.3571069550658609, 'optimizer': 'AdamW', 'lr': 0.0005667990506341249, 'weight_decay': 0.00010516326077523254, 'batch_size': 128}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #9/50
# [I 2025-05-17 15:18:58,713] Trial 8 finished with value: 0.8595668126829024 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.1476704220764743, 'optimizer': 'Adam', 'lr': 0.00020975299911925535, 'weight_decay': 3.1786047326041998e-06, 'batch_size': 128}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #10/50
# [I 2025-05-17 15:19:12,502] Trial 9 pruned.
# Starting Trial #11/50
# [I 2025-05-17 15:21:43,140] Trial 10 finished with value: 0.8601586595984627 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.24448259376491732, 'optimizer': 'AdamW', 'lr': 8.693214192795638e-05, 'weight_decay': 0.0004920189481367589, 'batch_size': 128}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #12/50
# [I 2025-05-17 15:23:18,541] Trial 11 finished with value: 0.8589987963439439 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.3921820177487373, 'optimizer': 'Adam', 'lr': 0.00010862227065236325, 'weight_decay': 1.4788972435536293e-05, 'batch_size': 512}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #13/50
# [I 2025-05-17 15:23:38,236] Trial 12 pruned.
# Starting Trial #14/50
# [I 2025-05-17 15:23:48,901] Trial 13 pruned.
# Starting Trial #15/50
# [I 2025-05-17 15:25:56,459] Trial 14 finished with value: 0.8597749757748314 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.39514728427884344, 'optimizer': 'Adam', 'lr': 0.0002709711275039597, 'weight_decay': 1.1705937006102515e-06, 'batch_size': 256}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #16/50
# [I 2025-05-17 15:26:15,037] Trial 15 pruned.
# Starting Trial #17/50
# [I 2025-05-17 15:26:37,309] Trial 16 pruned.
# Starting Trial #18/50
# [I 2025-05-17 15:29:23,297] Trial 17 finished with value: 0.8599989928559243 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.21256124943298027, 'optimizer': 'Adam', 'lr': 0.00015400748671343781, 'weight_decay': 8.452683255638875e-05, 'batch_size': 128}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #19/50
# [I 2025-05-17 15:29:33,980] Trial 18 pruned.
# Starting Trial #20/50
# [I 2025-05-17 15:31:15,785] Trial 19 finished with value: 0.8595546952837337 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.26742412140290545, 'optimizer': 'Adam', 'lr': 0.00030398990843289006, 'weight_decay': 0.00021297736914117137, 'batch_size': 256}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #21/50
# [I 2025-05-17 15:32:46,584] Trial 20 finished with value: 0.8601429153999475 and parameters: {'n_layers': 5, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.328573706071806, 'optimizer': 'Adam', 'lr': 0.0004098554786027507, 'weight_decay': 2.6989170955823284e-05, 'batch_size': 512}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #22/50
# [I 2025-05-17 15:34:17,282] Trial 21 finished with value: 0.8606916931093272 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.21363491618136277, 'optimizer': 'Adam', 'lr': 0.00038378552148170725, 'weight_decay': 6.595606393245259e-06, 'batch_size': 512}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #23/50
# [I 2025-05-17 15:35:46,365] Trial 22 finished with value: 0.8596676482970244 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.18943102602661466, 'optimizer': 'Adam', 'lr': 0.00034657963784305394, 'weight_decay': 6.2085689019598585e-06, 'batch_size': 512}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #24/50
# [I 2025-05-17 15:37:21,697] Trial 23 finished with value: 0.860564673484931 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.18661964954590193, 'optimizer': 'Adam', 'lr': 0.00015405858983936466, 'weight_decay': 1.6027235302214982e-06, 'batch_size': 512}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #25/50
# [I 2025-05-17 15:37:32,557] Trial 24 pruned.
# Starting Trial #26/50
# [I 2025-05-17 15:40:31,605] Trial 25 finished with value: 0.8598283653405837 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.17966937021519128, 'optimizer': 'Adam', 'lr': 5.336651346475396e-05, 'weight_decay': 2.3102851118148538e-06, 'batch_size': 128}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #27/50
# [I 2025-05-17 15:40:42,539] Trial 26 pruned.
# Starting Trial #28/50
# [I 2025-05-17 15:41:58,964] Trial 27 finished with value: 0.860507337735465 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.23935611258613915, 'optimizer': 'Adam', 'lr': 0.0006862640004062738, 'weight_decay': 4.0957274712214505e-05, 'batch_size': 512}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #29/50
# [I 2025-05-17 15:43:28,727] Trial 28 finished with value: 0.8603601660991012 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.19820798968737588, 'optimizer': 'Adam', 'lr': 0.0003467023336978121, 'weight_decay': 6.271145284104932e-06, 'batch_size': 256}. Best is trial 0 with value: 0.8612239440338515.
# Starting Trial #30/50
# [I 2025-05-17 15:45:51,626] Trial 29 finished with value: 0.8607001200073001 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.10385342491486507, 'optimizer': 'Adam', 'lr': 0.0007116987042170403, 'weight_decay': 1.6986476050989867e-06, 'batch_size': 128}. Best is trial 0 with value: 0.8612239440338515.
# [FOLD 4/5] Best hyperparameters:
#   - n_layers: 3
#   - hidden_size: 512
#   - activation: LeakyReLU
#   - dropout: 0.3320340702321666
#   - optimizer: Adam
#   - lr: 0.000420042405032095
#   - weight_decay: 8.384119791490705e-05
#   - batch_size: 128
#
# [FOLD 4/5] Training model with best hyperparameters...
#
# [FOLD 4/5] Results: F1=0.8590, AUC=0.8947
#
# [FOLD 5/5] Starting outer fold...
# [I 2025-05-17 15:46:55,776] A new study created in memory with name: no-name-257e8296-bb99-4413-8e98-77e507540ae6
# [FOLD 5/5] Starting hyperparameter search with Optuna...
# Starting Trial #1/50
# [I 2025-05-17 15:48:16,297] Trial 0 finished with value: 0.8600001825959467 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.14744095218438247, 'optimizer': 'AdamW', 'lr': 0.0009054049860464903, 'weight_decay': 2.3034050776282494e-06, 'batch_size': 512}. Best is trial 0 with value: 0.8600001825959467.
# Starting Trial #2/50
# [I 2025-05-17 15:49:38,520] Trial 1 finished with value: 0.8592832224121776 and parameters: {'n_layers': 2, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.36259210303910705, 'optimizer': 'Adam', 'lr': 0.000296129923107216, 'weight_decay': 1.0408298784239697e-06, 'batch_size': 512}. Best is trial 0 with value: 0.8600001825959467.
# Starting Trial #3/50
# [I 2025-05-17 15:51:09,515] Trial 2 finished with value: 0.8592545962087007 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.39686883371720794, 'optimizer': 'Adam', 'lr': 0.00037980008020812797, 'weight_decay': 2.102029275134119e-05, 'batch_size': 512}. Best is trial 0 with value: 0.8600001825959467.
# Starting Trial #4/50
# [I 2025-05-17 15:52:26,794] Trial 3 finished with value: 0.8594178387983047 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.2518373949901373, 'optimizer': 'AdamW', 'lr': 0.0009264968883980664, 'weight_decay': 1.3896158719104375e-06, 'batch_size': 512}. Best is trial 0 with value: 0.8600001825959467.
# Starting Trial #5/50
# [I 2025-05-17 15:58:51,464] Trial 4 finished with value: 0.859291744465569 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.20988399279201947, 'optimizer': 'AdamW', 'lr': 1.6140037402009053e-05, 'weight_decay': 5.948113070414239e-05, 'batch_size': 128}. Best is trial 0 with value: 0.8600001825959467.
# Starting Trial #6/50
# [I 2025-05-17 15:59:30,594] Trial 5 pruned.
# Starting Trial #7/50
# [I 2025-05-17 15:59:50,708] Trial 6 pruned.
# Starting Trial #8/50
# [I 2025-05-17 16:00:19,805] Trial 7 pruned.
# Starting Trial #9/50
# [I 2025-05-17 16:01:42,065] Trial 8 finished with value: 0.8593032311791786 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.32440091147139893, 'optimizer': 'AdamW', 'lr': 0.0004699083914609694, 'weight_decay': 8.93776778828163e-06, 'batch_size': 512}. Best is trial 0 with value: 0.8600001825959467.
# Starting Trial #10/50
# [I 2025-05-17 16:02:23,565] Trial 9 pruned.
# Starting Trial #11/50
# [I 2025-05-17 16:03:09,414] Trial 10 pruned.
# Starting Trial #12/50
# [I 2025-05-17 16:04:41,338] Trial 11 finished with value: 0.8589959837163205 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.24658432464683674, 'optimizer': 'AdamW', 'lr': 0.0009199457103444475, 'weight_decay': 4.229904643130947e-06, 'batch_size': 512}. Best is trial 0 with value: 0.8600001825959467.
# Starting Trial #13/50
# [I 2025-05-17 16:04:54,804] Trial 12 pruned.
# Starting Trial #14/50
# [I 2025-05-17 16:05:07,942] Trial 13 pruned.
# Starting Trial #15/50
# [I 2025-05-17 16:05:22,711] Trial 14 pruned.
# Starting Trial #16/50
# [I 2025-05-17 16:05:45,011] Trial 15 pruned.
# Starting Trial #17/50
# [I 2025-05-17 16:05:58,345] Trial 16 pruned.
# Starting Trial #18/50
# [I 2025-05-17 16:06:33,153] Trial 17 pruned.
# Starting Trial #19/50
# [I 2025-05-17 16:06:58,189] Trial 18 pruned.
# Starting Trial #20/50
# [I 2025-05-17 16:07:35,281] Trial 19 pruned.
# Starting Trial #21/50
# [I 2025-05-17 16:07:50,328] Trial 20 pruned.
# Starting Trial #22/50
# [I 2025-05-17 16:08:08,288] Trial 21 pruned.
# Starting Trial #23/50
# [I 2025-05-17 16:08:26,374] Trial 22 pruned.
# Starting Trial #24/50
# [I 2025-05-17 16:09:30,700] Trial 23 pruned.
# Starting Trial #25/50
# [I 2025-05-17 16:09:44,713] Trial 24 pruned.
# Starting Trial #26/50
# [I 2025-05-17 16:10:14,033] Trial 25 pruned.
# Starting Trial #27/50
# [I 2025-05-17 16:10:27,480] Trial 26 pruned.
# Starting Trial #28/50
# [I 2025-05-17 16:10:58,813] Trial 27 pruned.
# Starting Trial #29/50
# [I 2025-05-17 16:11:14,217] Trial 28 pruned.
# Starting Trial #30/50
# [I 2025-05-17 16:11:36,492] Trial 29 pruned.
# [FOLD 5/5] Best hyperparameters:
#   - n_layers: 4
#   - hidden_size: 256
#   - activation: ReLU
#   - dropout: 0.14744095218438247
#   - optimizer: AdamW
#   - lr: 0.0009054049860464903
#   - weight_decay: 2.3034050776282494e-06
#   - batch_size: 512
#
# [FOLD 5/5] Training model with best hyperparameters...
#
# [FOLD 5/5] Results: F1=0.8610, AUC=0.8979
#
# ================================================================================
#  NESTED CV COMPLETED
# ================================================================================
#
# [RESULTS] Nested CV Results:
#   - Avg F1=0.8603 (±0.0012)
#   - Avg AUC=0.8959 (±0.0015)
#
# [DETAILED FOLD RESULTS]
#   Fold 1: F1=0.8622, AUC=0.8963
#   Fold 2: F1=0.8600, AUC=0.8967
#   Fold 3: F1=0.8591, AUC=0.8938
#   Fold 4: F1=0.8590, AUC=0.8947
#   Fold 5: F1=0.8610, AUC=0.8979
#
# ================================================================================
#  DETERMINING BEST HYPERPARAMETERS FROM TOP-PERFORMING FOLD
# ================================================================================
#
# [BEST FOLD] Fold 1 with F1=0.8622, AUC=0.8963
#
# [FINAL HYPERPARAMETERS]
#   - n_layers: 4
#   - hidden_size: 384
#   - activation: ReLU
#   - dropout: 0.342427
#   - optimizer: AdamW
#   - lr: 0.000316
#   - weight_decay: 0.000956
#   - batch_size: 512
#
# ================================================================================
#  TRAINING FINAL MODEL WITH VALIDATION METRICS TRACKING
# ================================================================================
#
# [TRACKING] Training final model with metrics tracking...
# Epoch 1/100 - Train Loss: 0.4277, Val Loss: 0.3947, Train F1: 0.8503, Val F1: 0.8570
# Epoch 2/100 - Train Loss: 0.4025, Val Loss: 0.3954, Train F1: 0.8595, Val F1: 0.8593
# Epoch 3/100 - Train Loss: 0.3997, Val Loss: 0.3943, Train F1: 0.8598, Val F1: 0.8603
# Epoch 4/100 - Train Loss: 0.3981, Val Loss: 0.3947, Train F1: 0.8609, Val F1: 0.8586
# Epoch 5/100 - Train Loss: 0.3971, Val Loss: 0.3935, Train F1: 0.8615, Val F1: 0.8592
# Epoch 6/100 - Train Loss: 0.3962, Val Loss: 0.3945, Train F1: 0.8616, Val F1: 0.8589
# Epoch 7/100 - Train Loss: 0.3952, Val Loss: 0.3934, Train F1: 0.8623, Val F1: 0.8601
# Epoch 8/100 - Train Loss: 0.3932, Val Loss: 0.3933, Train F1: 0.8627, Val F1: 0.8614
# Epoch 9/100 - Train Loss: 0.3920, Val Loss: 0.3960, Train F1: 0.8628, Val F1: 0.8564
# Epoch 10/100 - Train Loss: 0.3910, Val Loss: 0.3950, Train F1: 0.8631, Val F1: 0.8611
# Epoch 11/100 - Train Loss: 0.3897, Val Loss: 0.3940, Train F1: 0.8638, Val F1: 0.8605
# Epoch 12/100 - Train Loss: 0.3854, Val Loss: 0.3959, Train F1: 0.8661, Val F1: 0.8562
# Epoch 13/100 - Train Loss: 0.3834, Val Loss: 0.3944, Train F1: 0.8669, Val F1: 0.8603
# Epoch 14/100 - Train Loss: 0.3807, Val Loss: 0.3956, Train F1: 0.8682, Val F1: 0.8587
# Epoch 15/100 - Train Loss: 0.3768, Val Loss: 0.3973, Train F1: 0.8693, Val F1: 0.8582
# Epoch 16/100 - Train Loss: 0.3745, Val Loss: 0.3971, Train F1: 0.8713, Val F1: 0.8596
# Epoch 17/100 - Train Loss: 0.3722, Val Loss: 0.3976, Train F1: 0.8719, Val F1: 0.8585
# Epoch 18/100 - Train Loss: 0.3688, Val Loss: 0.3993, Train F1: 0.8733, Val F1: 0.8592
# Early stopping triggered! No significant improvement for 10 epochs.
# Best epoch was 8 with validation loss: 0.393285
# [RESULTS] Best validation loss: 0.3933, F1: 0.8614 at epoch 8
#
# [METRICS] At best epoch 8:
#   - Training Loss: 0.3932
#   - Validation Loss: 0.3933
#   - Training F1: 0.8627
#   - Validation F1: 0.8614
# [CONCLUSION] Based on the validation F1 score curves, the optimal number of epochs
#              for training the final model is: 8

# %%
# STEP 4: EVALUATE ON TEST SET
print("\n" + "="*80)
print(" EVALUATING FINAL MODEL ON TEST SET")
print("="*80)

# Create test data loader
test_loader = DataLoader(
    TensorDataset(X_test, y_test),
    batch_size=final_params['batch_size'],
    shuffle=False,
    **loader_kwargs
)

# Evaluate on test set
final_model.eval()
test_preds = []
test_labels = []

with torch.no_grad():
    for xb, yb in test_loader:
        xb, yb = xb.to(device), yb.to(device)
        outputs = final_model(xb)

        test_preds.append(torch.sigmoid(outputs).cpu())
        test_labels.append(yb.cpu())

# Calculate and report metrics
test_preds_cat = torch.cat(test_preds).numpy()
test_labels_cat = torch.cat(test_labels).numpy()
test_preds_bin = (test_preds_cat > 0.5).astype(int)

# Calculate metrics
test_f1 = f1_score(test_labels_cat, test_preds_bin)
test_precision = precision_score(test_labels_cat, test_preds_bin)
test_recall = recall_score(test_labels_cat, test_preds_bin)
test_auc = roc_auc_score(test_labels_cat, test_preds_cat)

# Print results
print("\n[TEST RESULTS]")
print(f"  - F1 Score: {test_f1:.4f}")
print(f"  - Precision: {test_precision:.4f}")
print(f"  - Recall: {test_recall:.4f}")
print(f"  - AUC: {test_auc:.4f}")

# Confusion Matrix
cm = confusion_matrix(test_labels_cat, test_preds_bin)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix on Test Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(test_labels_cat, test_preds_cat)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {test_auc:.4f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve on Test Set')
plt.legend()
plt.grid(True)
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(test_labels_cat, test_preds_cat)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve on Test Set')
plt.grid(True)
plt.show()

# Save model
model_path = "/content/drive/MyDrive/Finetuned_mlp_final_code_result/Finetuned_mlp_2_code_result (1)/final_trained_model.pt"
torch.save({
    'model_state_dict': final_model.state_dict(),
    'hyperparameters': final_params,
    'metrics': {
        'train_f1': metrics['train_f1s'][metrics['best_epoch']],
        'val_f1': metrics['val_f1s'][metrics['best_epoch']],
        'test_f1': test_f1,
        'test_precision': test_precision,
        'test_recall': test_recall,
        'test_auc': test_auc
    }
}, model_path)

print(f"\n[INFO] Final model saved to {model_path}")
# Out:
# ================================================================================
#  EVALUATING FINAL MODEL ON TEST SET
# ================================================================================
#
# [TEST RESULTS]
#   - F1 Score: 0.8226
#   - Precision: 0.7897
#   - Recall: 0.8584
#   - AUC: 0.8420
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-405f1618b062> in <cell line: 0>()
#      76 # Save model
#      77 model_path = "/content/drive/MyDrive/Finetuned_mlp_final_code_result/Finetuned_mlp_2_code_result (1)/final_trained_model.pt"
# ---> 78 torch.save({
#      79     'model_state_dict': final_model.state_dict(),
#      80     'hyperparameters': final_params,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     941
#     942     if _use_new_zipfile_serialization:
# --> 943         with _open_zipfile_writer(f) as opened_zipfile:
#     944             _save(
#     945                 obj,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _open_zipfile_writer(name_or_buffer)
#     808     else:
#     809         container = _open_zipfile_writer_buffer
# --> 810     return container(name_or_buffer)
#     811
#     812
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in __init__(self, name)
#     779             )
#     780         else:
# --> 781             super().__init__(torch._C.PyTorchFileWriter(self.name, _compute_crc32))
#     782
#     783     def __exit__(self, *args) -> None:
#
# RuntimeError: Parent directory /content/drive/MyDrive/Finetuned_mlp_final_code_result/Finetuned_mlp_2_code_result (1) does not exist.
