# %%
! pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 13.2 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 26.8 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import StratifiedKFold, train_test_split

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
import matplotlib.pyplot as plt
import optuna
import copy
import random
import os
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pickle
from sklearn.metrics import precision_score, recall_score, precision_recall_curve, roc_curve, f1_score, confusion_matrix, roc_auc_score
pd.set_option('display.max_columns', None)

# %%
# Set global seed for reproducibility
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set the seed and device
seed_everything(42)
epochs = 100
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("[INFO] Device:", device)

# Load CSVs
train_val_df = pd.read_csv('/content/drive/MyDrive/Thesis/Final/pretrained_embeddings_train_val_final.csv')
test_df = pd.read_csv('/content/drive/MyDrive/Thesis/Final/pretrained_embeddings_test_final.csv')

# Prepare data (keep on CPU)
X_train_val_np = train_val_df.iloc[:, 0:768].values
y_train_val_np = train_val_df['state_binary'].values

X_test_np = test_df.iloc[:, 0:768].values
y_test_np = test_df['state_binary'].values

# Convert to tensors on CPU
X_train_val = torch.tensor(X_train_val_np, dtype=torch.float32)
y_train_val = torch.tensor(y_train_val_np.reshape(-1, 1), dtype=torch.float32)

X_test = torch.tensor(X_test_np, dtype=torch.float32)
y_test = torch.tensor(y_test_np.reshape(-1, 1), dtype=torch.float32)

print(f"[INFO] Train/Val: {X_train_val.shape[0]} samples x {X_train_val.shape[1]} dims")
print(f"[INFO] Test:      {X_test.shape[0]} samples x {X_test.shape[1]} dims")

# Model definition
def build_model(input_size, trial):
    n_layers = trial.suggest_int("n_layers", 2, 5)
    base_hidden_size = trial.suggest_categorical("hidden_size", [256, 384, 512])
    activation = trial.suggest_categorical("activation", ["ReLU", "LeakyReLU"])
    dropout = trial.suggest_float("dropout", 0.1, 0.4)

    layers = []
    in_features = input_size
    for i in range(n_layers):
        hidden_size = max(int(base_hidden_size // (2 ** i)), 32)
        layers.append(nn.Linear(in_features, hidden_size))

        if activation == "LeakyReLU":
            layers.append(nn.LeakyReLU(0.1))
        else:
            layers.append(getattr(nn, activation)())

        layers.append(nn.Dropout(dropout))
        in_features = hidden_size

    layers.append(nn.Linear(in_features, 1))
    return nn.Sequential(*layers).to(device)

# Training function
loader_kwargs = dict(num_workers=4, pin_memory=True)


def train_model(model, train_loader, val_loader, optimizer, criterion, epochs, patience=10, trial=None, fold_offset=0, delta=1e-4):
    best_val_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    best_f1 = 0.0

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=2
    )

    for epoch in range(epochs):
        model.train()
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            preds = model(xb)
            loss = criterion(preds, yb)
            loss.backward()
            optimizer.step()

        model.eval()
        val_losses, all_preds, all_labels = [], [], []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                preds = model(xb)
                val_losses.append(criterion(preds, yb).item())
                all_preds.append(torch.sigmoid(preds).cpu())
                all_labels.append(yb.cpu())

        avg_val_loss = np.mean(val_losses)
        preds_bin = (torch.cat(all_preds).numpy() > 0.5).astype(int)
        labels_cat = torch.cat(all_labels).numpy()
        val_f1 = f1_score(labels_cat, preds_bin)

        scheduler.step(avg_val_loss)

        if trial:
            trial.report(val_f1, step=fold_offset + epoch)
            if trial.should_prune():
                raise optuna.exceptions.TrialPruned()

        # Early stopping
        if avg_val_loss < best_val_loss - delta:  # Only consider improvement > delta
            best_val_loss = avg_val_loss
            best_f1 = val_f1
            best_model_state = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                break

    if best_model_state:
        model.load_state_dict(best_model_state)

    return model, best_f1


# STEP 2: NESTED CV
outer_folds = 5
outer_cv = StratifiedKFold(n_splits=outer_folds, shuffle=True, random_state=42)
outer_results = []

print("\n" + "="*80)
print(" STARTING NESTED CROSS-VALIDATION")
print("="*80)

for outer_fold, (train_idx, val_idx) in enumerate(outer_cv.split(X_train_val.numpy(), y_train_val.numpy())):
    print(f"\n[FOLD {outer_fold + 1}/{outer_folds}] Starting outer fold...")
    X_train_outer = X_train_val[train_idx]
    y_train_outer = y_train_val[train_idx]
    X_val_outer   = X_train_val[val_idx]
    y_val_outer   = y_train_val[val_idx]

    def objective(trial):
        print(f"Starting Trial #{trial.number+1}/50")
        model = build_model(X_train_outer.shape[1], trial)

        optimizer_name  = trial.suggest_categorical("optimizer", ["Adam", "AdamW"])
        lr              = trial.suggest_float("lr", 1e-5, 1e-3, log=True)
        weight_decay    = trial.suggest_float("weight_decay", 1e-6, 1e-3, log=True)
        batch_size      = trial.suggest_categorical("batch_size", [128, 256, 512])



        patience_param = 10
        criterion = nn.BCEWithLogitsLoss()

        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
        f1_scores = []

        for fold_idx, (tr_idx, va_idx) in enumerate(skf.split(X_train_outer.numpy(), y_train_outer.numpy())):
            X_tr, y_tr = X_train_outer[tr_idx], y_train_outer[tr_idx]
            X_va, y_va = X_train_outer[va_idx], y_train_outer[va_idx]

            train_loader = DataLoader(
                TensorDataset(X_tr, y_tr),
                batch_size=batch_size,
                shuffle=True,
                **loader_kwargs
            )
            val_loader = DataLoader(
                TensorDataset(X_va, y_va),
                batch_size=batch_size,
                shuffle=False,
                **loader_kwargs
            )

            model_copy = copy.deepcopy(model)
            optimizer = getattr(optim, optimizer_name)(
                model_copy.parameters(), lr=lr, weight_decay=weight_decay
            )

            # Suppress output during inner CV by passing trial
            trained_model, _ = train_model(
                model_copy, train_loader, val_loader,
                optimizer, criterion, epochs, patience_param,
                trial, fold_idx * epochs
            )

            trained_model.eval()
            with torch.no_grad():
                xb, yb = X_va.to(device), y_va.to(device)
                preds = torch.sigmoid(trained_model(xb)).cpu().numpy()
                preds_bin = (preds > 0.5).astype(int)
                f1_score_fold = f1_score(yb.cpu().numpy(), preds_bin)
                f1_scores.append(f1_score_fold)

        return np.mean(f1_scores)

    print(f"[FOLD {outer_fold + 1}/{outer_folds}] Starting hyperparameter search with Optuna...")

    # Configure Optuna logging to be more concise
    optuna.logging.set_verbosity(optuna.logging.INFO)
    sampler = optuna.samplers.TPESampler(seed=42)
    study = optuna.create_study(
        direction="maximize",
        pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=5)
    )
    study.optimize(objective, n_trials=30)

    best_params = study.best_trial.params
    print(f"\n[FOLD {outer_fold + 1}/{outer_folds}] Best hyperparameters:")
    for param_name, param_value in best_params.items():
        print(f"  - {param_name}: {param_value}")

    # Evaluate on outer validation
    print(f"\n[FOLD {outer_fold + 1}/{outer_folds}] Training model with best hyperparameters...")
    final_model = build_model(X_train_outer.shape[1], optuna.trial.FixedTrial(best_params))
    optimizer  = getattr(optim, best_params['optimizer'])(
        final_model.parameters(),
        lr=best_params['lr'],
        weight_decay=best_params['weight_decay']
    )



    criterion = nn.BCEWithLogitsLoss()

    train_loader = DataLoader(
        TensorDataset(X_train_outer, y_train_outer),
        batch_size=best_params['batch_size'], shuffle=True,
        **loader_kwargs
    )
    val_loader = DataLoader(
        TensorDataset(X_val_outer, y_val_outer),
        batch_size=best_params['batch_size'],
        shuffle=False,
        **loader_kwargs
    )

    final_model, _ = train_model(
        final_model, train_loader, val_loader,
        optimizer, criterion, epochs, patience=10, delta=1e-4
    )

    final_model.eval()
    with torch.no_grad():
        xb, yb = X_val_outer.to(device), y_val_outer.to(device)
        preds = torch.sigmoid(final_model(xb)).cpu().numpy()
        preds_bin = (preds > 0.5).astype(int)
        f1 = f1_score(yb.cpu().numpy(), preds_bin)
        auc = roc_auc_score(yb.cpu().numpy(), preds)
        print(f"\n[FOLD {outer_fold+1}/{outer_folds}] Results: F1={f1:.4f}, AUC={auc:.4f}")

    outer_results.append({
        "fold": outer_fold + 1,
        "f1": f1,
        "auc": auc,
        "params": best_params
    })

print("\n" + "="*80)
print(" NESTED CV COMPLETED")
print("="*80)

# Calculate mean performance across outer folds
mean_f1 = np.mean([r["f1"] for r in outer_results])
mean_auc = np.mean([r["auc"] for r in outer_results])
std_f1 = np.std([r["f1"] for r in outer_results])
std_auc = np.std([r["auc"] for r in outer_results])

print(f"\n[RESULTS] Nested CV Results: ")
print(f"  - Avg F1={mean_f1:.4f} (±{std_f1:.4f})")
print(f"  - Avg AUC={mean_auc:.4f} (±{std_auc:.4f})")

# Print detailed results for each fold
print("\n[DETAILED FOLD RESULTS]")
for res in outer_results:
    print(f"  Fold {res['fold']}: F1={res['f1']:.4f}, AUC={res['auc']:.4f}")

# STEP 3: DETERMINE BEST HYPERPARAMETERS FROM BEST FOLD
print("\n" + "="*80)
print(" DETERMINING BEST HYPERPARAMETERS FROM TOP-PERFORMING FOLD")
print("="*80)

# Find the best-performing fold based on F1 score
best_fold_idx = np.argmax([r["f1"] for r in outer_results])
best_fold_params = outer_results[best_fold_idx]["params"]
best_fold_f1 = outer_results[best_fold_idx]["f1"]
best_fold_auc = outer_results[best_fold_idx]["auc"]

# Use the parameters from the best fold
final_params = best_fold_params.copy()

print(f"\n[BEST FOLD] Fold {best_fold_idx + 1} with F1={best_fold_f1:.4f}, AUC={best_fold_auc:.4f}")
print("\n[FINAL HYPERPARAMETERS]")
for key, value in final_params.items():
    if isinstance(value, float):
        print(f"  - {key}: {value:.6f}")
    else:
        print(f"  - {key}: {value}")

# STEP 3: FINAL TRAIN+VAL EVALUATION WITH METRIC TRACKING
print("\n" + "="*80)
print(" TRAINING FINAL MODEL WITH VALIDATION METRICS TRACKING")
print("="*80)

# Create fixed trial with the best parameters
fixed_trial = optuna.trial.FixedTrial(final_params)

# Initialize the final model
final_model = build_model(X_train_val.shape[1], fixed_trial)
optimizer = getattr(optim, final_params['optimizer'])(
    final_model.parameters(),
    lr=final_params['lr'],
    weight_decay=final_params['weight_decay']
)
criterion = nn.BCEWithLogitsLoss()

# Split train_val data into train and validation sets
X_train_final, X_val_final, y_train_final, y_val_final = train_test_split(
    X_train_val.numpy(), y_train_val.numpy(),
    test_size=0.1, stratify=y_train_val.numpy(), random_state=42
)

# Convert back to tensors
X_train_final = torch.tensor(X_train_final, dtype=torch.float32)
y_train_final = torch.tensor(y_train_final, dtype=torch.float32)
X_val_final = torch.tensor(X_val_final, dtype=torch.float32)
y_val_final = torch.tensor(y_val_final, dtype=torch.float32)

# Create data loaders
train_loader = DataLoader(
    TensorDataset(X_train_final, y_train_final),
    batch_size=final_params['batch_size'],
    shuffle=True,
    **loader_kwargs
)

val_loader = DataLoader(
    TensorDataset(X_val_final, y_val_final),
    batch_size=final_params['batch_size'],
    shuffle=False,
    **loader_kwargs
)


# Metrics tracking function with validation loss as early stopping criterion
def train_with_metrics(model, train_loader, val_loader, optimizer, criterion, epochs, patience=10, delta=1e-4):
    best_val_loss = float('inf')
    best_epoch = 0
    wait = 0
    best_state = copy.deepcopy(model.state_dict())

    # Lists to store metrics
    train_losses = []
    val_losses = []
    train_f1s = []
    val_f1s = []

    # Learning Rate Scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=2
    )

    for epoch in range(epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        train_preds = []
        train_labels = []

        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            outputs = final_model(xb)
            loss = criterion(outputs, yb)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * len(xb)
            train_preds.append(torch.sigmoid(outputs).detach().cpu())
            train_labels.append(yb.detach().cpu())

        # Calculate training metrics
        train_loss /= len(train_loader.dataset)
        train_preds_cat = torch.cat(train_preds).numpy()
        train_labels_cat = torch.cat(train_labels).numpy()
        train_f1 = f1_score(train_labels_cat, (train_preds_cat > 0.5).astype(int))

        # Validation phase
        model.eval()
        val_loss = 0.0
        val_preds = []
        val_labels = []

        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                outputs = final_model(xb)
                loss = criterion(outputs, yb)
                val_loss += loss.item() * len(xb)

                val_preds.append(torch.sigmoid(outputs).cpu())
                val_labels.append(yb.cpu())

        # Calculate validation metrics
        val_loss /= len(val_loader.dataset)
        val_preds_cat = torch.cat(val_preds).numpy()
        val_labels_cat = torch.cat(val_labels).numpy()
        val_f1 = f1_score(val_labels_cat, (val_preds_cat > 0.5).astype(int))

        scheduler.step(val_loss)

        # Store metrics
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_f1s.append(train_f1)
        val_f1s.append(val_f1)

        # Print progress
        print(f"Epoch {epoch+1}/{epochs} - Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, "
              f"Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}")

        # Early stopping check (based on validation loss with delta=1e-4)
        if val_loss < best_val_loss - delta:  # Only save if improvement is greater than delta
            best_val_loss = val_loss
            best_epoch = epoch
            best_state = copy.deepcopy(model.state_dict())
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                print(f"Early stopping triggered! No significant improvement for {patience} epochs.")
                print(f"Best epoch was {best_epoch+1} with validation loss: {best_val_loss:.6f}")
                break

    # Restore best model
    model.load_state_dict(best_state)

    # Plot training curves
    plt.figure(figsize=(15, 10))

    # Loss curves
    plt.subplot(2, 1, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.axvline(x=best_epoch, color='r', linestyle='--',
                label=f'Best Epoch ({best_epoch+1})')
    plt.title('Loss Curves')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # F1 score curves
    plt.subplot(2, 1, 2)
    plt.plot(train_f1s, label='Training F1')
    plt.plot(val_f1s, label='Validation F1')
    plt.axvline(x=best_epoch, color='r', linestyle='--',
                label=f'Best Epoch ({best_epoch+1})')
    plt.title('F1 Score Curves')
    plt.xlabel('Epoch')
    plt.ylabel('F1 Score')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

    # Return model and metrics
    return model, {
        'best_epoch': best_epoch,
        'best_val_loss': best_val_loss,
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_f1s': train_f1s,
        'val_f1s': val_f1s
    }

# Train with metrics tracking
print("\n[TRACKING] Training final model with metrics tracking...")
final_model, metrics = train_with_metrics(
    final_model, train_loader, val_loader,
    optimizer, criterion, epochs=epochs, patience=10, delta=1e-4
)

# Print results
print(f"\n[RESULTS] Best validation loss: {metrics['best_val_loss']:.4f}, F1: {metrics['val_f1s'][metrics['best_epoch']]:.4f} at epoch {metrics['best_epoch']+1}")

# Calculate and display metrics at best epoch
best_epoch = metrics['best_epoch']
print(f"\n[METRICS] At best epoch {best_epoch+1}:")
print(f"  - Training Loss: {metrics['train_losses'][best_epoch]:.4f}")
print(f"  - Validation Loss: {metrics['val_losses'][best_epoch]:.4f}")
print(f"  - Training F1: {metrics['train_f1s'][best_epoch]:.4f}")
print(f"  - Validation F1: {metrics['val_f1s'][best_epoch]:.4f}")

# Apply smoothing to the curves
from scipy.signal import savgol_filter

# Function to apply smoothing
def apply_smoothing(data, window_length=5, polyorder=2):
    if len(data) <= window_length:
        return data  # Not enough data points for smoothing

    # Ensure window_length is odd
    if window_length % 2 == 0:
        window_length += 1

    return savgol_filter(data, window_length, polyorder)

# Plot smoothed curves
plt.figure(figsize=(15, 10))

# Loss curves (smoothed)
plt.subplot(2, 1, 1)
train_losses = metrics['train_losses']
val_losses = metrics['val_losses']

if len(train_losses) >= 5:  # Only smooth if we have enough points
    train_losses_smooth = apply_smoothing(train_losses)
    val_losses_smooth = apply_smoothing(val_losses)

    plt.plot(train_losses, 'b-', alpha=0.3, label='Training Loss (Raw)')
    plt.plot(val_losses, 'orange', alpha=0.3, label='Validation Loss (Raw)')
    plt.plot(train_losses_smooth, 'b-', linewidth=2, label='Training Loss (Smoothed)')
    plt.plot(val_losses_smooth, 'orange', linewidth=2, label='Validation Loss (Smoothed)')
else:
    plt.plot(train_losses, 'b-', label='Training Loss')
    plt.plot(val_losses, 'orange', label='Validation Loss')

plt.axvline(x=best_epoch, color='r', linestyle='--', label=f'Best Epoch ({best_epoch+1})')
plt.title('Loss Curves (Smoothed)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# F1 score curves (smoothed)
plt.subplot(2, 1, 2)
train_f1s = metrics['train_f1s']
val_f1s = metrics['val_f1s']

if len(train_f1s) >= 5:  # Only smooth if we have enough points
    train_f1s_smooth = apply_smoothing(train_f1s)
    val_f1s_smooth = apply_smoothing(val_f1s)

    plt.plot(train_f1s, 'b-', alpha=0.3, label='Training F1 (Raw)')
    plt.plot(val_f1s, 'orange', alpha=0.3, label='Validation F1 (Raw)')
    plt.plot(train_f1s_smooth, 'b-', linewidth=2, label='Training F1 (Smoothed)')
    plt.plot(val_f1s_smooth, 'orange', linewidth=2, label='Validation F1 (Smoothed)')
else:
    plt.plot(train_f1s, 'b-', label='Training F1')
    plt.plot(val_f1s, 'orange', label='Validation F1')

plt.axvline(x=best_epoch, color='r', linestyle='--', label=f'Best Epoch ({best_epoch+1})')
plt.title('F1 Score Curves (Smoothed)')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

print("\n[CONCLUSION] Based on the validation F1 score curves, the optimal number of epochs")
print(f"             for training the final model is: {best_epoch+1}")
# Out:
# [INFO] Device: cuda
# [I 2025-05-17 12:45:48,244] A new study created in memory with name: no-name-7d990692-a7ad-4cee-a9b0-477593778e0d
# [INFO] Train/Val: 146089 samples x 768 dims
# [INFO] Test:      16233 samples x 768 dims
#
# ================================================================================
#  STARTING NESTED CROSS-VALIDATION
# ================================================================================
#
# [FOLD 1/5] Starting outer fold...
# [FOLD 1/5] Starting hyperparameter search with Optuna...
# Starting Trial #1/50
# [I 2025-05-17 12:48:12,325] Trial 0 finished with value: 0.8070147574676853 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.13353182251668766, 'optimizer': 'AdamW', 'lr': 5.4535602644696914e-05, 'weight_decay': 0.00015763496244463322, 'batch_size': 512}. Best is trial 0 with value: 0.8070147574676853.
# Starting Trial #2/50
# [I 2025-05-17 12:52:45,756] Trial 1 finished with value: 0.8076429575647754 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.20461914789033336, 'optimizer': 'AdamW', 'lr': 3.668312751104307e-05, 'weight_decay': 0.00014808235958180054, 'batch_size': 512}. Best is trial 1 with value: 0.8076429575647754.
# Starting Trial #3/50
# [I 2025-05-17 12:54:14,942] Trial 2 finished with value: 0.8088750264185967 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.20514088768295322, 'optimizer': 'Adam', 'lr': 0.00025900913385788657, 'weight_decay': 0.00011508425214448896, 'batch_size': 512}. Best is trial 2 with value: 0.8088750264185967.
# Starting Trial #4/50
# [I 2025-05-17 12:55:53,698] Trial 3 finished with value: 0.8087832450428213 and parameters: {'n_layers': 3, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.2723165171656854, 'optimizer': 'AdamW', 'lr': 0.00018573251194112188, 'weight_decay': 8.431604570905266e-05, 'batch_size': 256}. Best is trial 2 with value: 0.8088750264185967.
# Starting Trial #5/50
# [I 2025-05-17 12:58:07,088] Trial 4 finished with value: 0.8096929617855325 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.18651852829775545, 'optimizer': 'Adam', 'lr': 0.00010043142784530206, 'weight_decay': 7.202997312850468e-05, 'batch_size': 256}. Best is trial 4 with value: 0.8096929617855325.
# Starting Trial #6/50
# [I 2025-05-17 12:58:13,823] Trial 5 pruned.
# Starting Trial #7/50
# [I 2025-05-17 12:58:23,523] Trial 6 pruned.
# Starting Trial #8/50
# [I 2025-05-17 12:58:45,561] Trial 7 pruned.
# Starting Trial #9/50
# [I 2025-05-17 12:59:17,057] Trial 8 pruned.
# Starting Trial #10/50
# [I 2025-05-17 12:59:40,182] Trial 9 pruned.
# Starting Trial #11/50
# [I 2025-05-17 13:02:57,141] Trial 10 finished with value: 0.8089025805702965 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.2567371694401087, 'optimizer': 'Adam', 'lr': 0.0009985279107549518, 'weight_decay': 0.0009532032894005913, 'batch_size': 256}. Best is trial 4 with value: 0.8096929617855325.
# Starting Trial #12/50
# [I 2025-05-17 13:05:32,859] Trial 11 finished with value: 0.810417743479162 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.255465716023359, 'optimizer': 'Adam', 'lr': 0.0007509182103714505, 'weight_decay': 0.0008709247877240027, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #13/50
# [I 2025-05-17 13:06:46,613] Trial 12 finished with value: 0.8058467533336993 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.20412056409652743, 'optimizer': 'Adam', 'lr': 0.0009921851149588933, 'weight_decay': 2.789222445705081e-06, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #14/50
# [I 2025-05-17 13:08:12,916] Trial 13 finished with value: 0.8094679231335452 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.3266277489164182, 'optimizer': 'Adam', 'lr': 0.0004190564958783455, 'weight_decay': 3.590933485320543e-05, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #15/50
# [I 2025-05-17 13:08:23,213] Trial 14 pruned.
# Starting Trial #16/50
# [I 2025-05-17 13:08:32,618] Trial 15 pruned.
# Starting Trial #17/50
# [I 2025-05-17 13:09:52,964] Trial 16 finished with value: 0.8095191087734256 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.2234439916898034, 'optimizer': 'Adam', 'lr': 0.000493090771607965, 'weight_decay': 1.1106515386946142e-05, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #18/50
# [I 2025-05-17 13:10:03,668] Trial 17 pruned.
# Starting Trial #19/50
# [I 2025-05-17 13:10:13,164] Trial 18 pruned.
# Starting Trial #20/50
# [I 2025-05-17 13:13:15,950] Trial 19 finished with value: 0.8046403174911484 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.3678945080733678, 'optimizer': 'Adam', 'lr': 0.00042896338882364215, 'weight_decay': 5.9702480609244485e-05, 'batch_size': 128}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #21/50
# [I 2025-05-17 13:15:12,064] Trial 20 finished with value: 0.8060443515906773 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.3052025802803613, 'optimizer': 'Adam', 'lr': 0.00024146387029659304, 'weight_decay': 0.00034251886828437885, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #22/50
# [I 2025-05-17 13:16:38,699] Trial 21 finished with value: 0.8099883617287081 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.2277632127391026, 'optimizer': 'Adam', 'lr': 0.0005597681761906898, 'weight_decay': 1.0296889320144996e-05, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #23/50
# [I 2025-05-17 13:18:15,293] Trial 22 finished with value: 0.8056374869713494 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.23266475110348928, 'optimizer': 'Adam', 'lr': 0.0006184010009470716, 'weight_decay': 6.096905668347969e-06, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #24/50
# [I 2025-05-17 13:19:32,143] Trial 23 finished with value: 0.8087831608649666 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.17359731528346195, 'optimizer': 'Adam', 'lr': 0.0006950877090744867, 'weight_decay': 1.149819307230635e-05, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #25/50
# [I 2025-05-17 13:21:08,779] Trial 24 finished with value: 0.8073151994287685 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.27054705520714845, 'optimizer': 'Adam', 'lr': 0.00032223072648011886, 'weight_decay': 5.505332614155039e-05, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #26/50
# [I 2025-05-17 13:22:43,006] Trial 25 finished with value: 0.8076426631799519 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.17601428494511015, 'optimizer': 'Adam', 'lr': 0.00013652556397896574, 'weight_decay': 2.9850152988007147e-06, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #27/50
# [I 2025-05-17 13:24:09,625] Trial 26 finished with value: 0.809691148493899 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.3471893130536355, 'optimizer': 'Adam', 'lr': 0.0006963442695783548, 'weight_decay': 1.6668847059999176e-05, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #28/50
# [I 2025-05-17 13:25:57,924] Trial 27 finished with value: 0.804196332238693 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.2150195082068301, 'optimizer': 'Adam', 'lr': 0.0003169827189871499, 'weight_decay': 0.0005830771278193133, 'batch_size': 256}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #29/50
# [I 2025-05-17 13:27:37,193] Trial 28 finished with value: 0.8087490030204233 and parameters: {'n_layers': 2, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.25162583562289725, 'optimizer': 'Adam', 'lr': 0.00017279205867640624, 'weight_decay': 5.047383981481415e-06, 'batch_size': 512}. Best is trial 11 with value: 0.810417743479162.
# Starting Trial #30/50
# [I 2025-05-17 13:28:14,416] Trial 29 pruned.
# [FOLD 1/5] Best hyperparameters:
#   - n_layers: 2
#   - hidden_size: 512
#   - activation: ReLU
#   - dropout: 0.255465716023359
#   - optimizer: Adam
#   - lr: 0.0007509182103714505
#   - weight_decay: 0.0008709247877240027
#   - batch_size: 256
#
# [FOLD 1/5] Training model with best hyperparameters...
# [I 2025-05-17 13:29:37,495] A new study created in memory with name: no-name-6bd67759-c574-407a-ba55-fe38a12f3e37
# [FOLD 1/5] Results: F1=0.8129, AUC=0.8294
#
# [FOLD 2/5] Starting outer fold...
# [FOLD 2/5] Starting hyperparameter search with Optuna...
# Starting Trial #1/50
# [I 2025-05-17 13:32:25,535] Trial 0 finished with value: 0.8069915069780705 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.13793623659081755, 'optimizer': 'Adam', 'lr': 0.0003533318937916357, 'weight_decay': 0.0001556473116779333, 'batch_size': 128}. Best is trial 0 with value: 0.8069915069780705.
# Starting Trial #2/50
# [I 2025-05-17 13:34:25,013] Trial 1 finished with value: 0.8089262539170058 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.2517930483385923, 'optimizer': 'Adam', 'lr': 0.0005617839086823615, 'weight_decay': 2.95008214813952e-06, 'batch_size': 256}. Best is trial 1 with value: 0.8089262539170058.
# Starting Trial #3/50
# [I 2025-05-17 13:41:10,552] Trial 2 finished with value: 0.8060984974302515 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.38577001248332243, 'optimizer': 'Adam', 'lr': 2.8175948798714858e-05, 'weight_decay': 6.3596166248525186e-06, 'batch_size': 128}. Best is trial 1 with value: 0.8089262539170058.
# Starting Trial #4/50
# [I 2025-05-17 13:42:54,783] Trial 3 finished with value: 0.8100845166867271 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.32977974784063896, 'optimizer': 'AdamW', 'lr': 0.0007542271154839152, 'weight_decay': 0.0005266684806028177, 'batch_size': 256}. Best is trial 3 with value: 0.8100845166867271.
# Starting Trial #5/50
# [I 2025-05-17 13:45:16,027] Trial 4 finished with value: 0.8107089576924612 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.17106767741302492, 'optimizer': 'AdamW', 'lr': 0.00011725593937961035, 'weight_decay': 0.000303211810438113, 'batch_size': 256}. Best is trial 4 with value: 0.8107089576924612.
# Starting Trial #6/50
# [I 2025-05-17 13:45:31,779] Trial 5 pruned.
# Starting Trial #7/50
# [I 2025-05-17 13:47:25,468] Trial 6 finished with value: 0.8080598202918577 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.3384143837494114, 'optimizer': 'AdamW', 'lr': 0.0002348550182860089, 'weight_decay': 5.5945705216375694e-05, 'batch_size': 256}. Best is trial 4 with value: 0.8107089576924612.
# Starting Trial #8/50
# [I 2025-05-17 13:51:19,080] Trial 7 finished with value: 0.8049273033940588 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.30966285144151906, 'optimizer': 'Adam', 'lr': 0.0009152957827254146, 'weight_decay': 0.00024216069086404558, 'batch_size': 128}. Best is trial 4 with value: 0.8107089576924612.
# Starting Trial #9/50
# [I 2025-05-17 13:52:30,939] Trial 8 finished with value: 0.8030397409521376 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.23587356958103947, 'optimizer': 'Adam', 'lr': 0.0008553340044101902, 'weight_decay': 1.0654326128428252e-05, 'batch_size': 512}. Best is trial 4 with value: 0.8107089576924612.
# Starting Trial #10/50
# [I 2025-05-17 13:52:38,897] Trial 9 pruned.
# Starting Trial #11/50
# [I 2025-05-17 13:52:51,064] Trial 10 pruned.
# Starting Trial #12/50
# [I 2025-05-17 13:53:09,005] Trial 11 pruned.
# Starting Trial #13/50
# [I 2025-05-17 13:53:19,943] Trial 12 pruned.
# Starting Trial #14/50
# [I 2025-05-17 13:55:22,339] Trial 13 finished with value: 0.8084835536157584 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.1842948991404072, 'optimizer': 'AdamW', 'lr': 0.0002566231375766337, 'weight_decay': 0.0004222401257085639, 'batch_size': 256}. Best is trial 4 with value: 0.8107089576924612.
# Starting Trial #15/50
# [I 2025-05-17 13:55:33,091] Trial 14 pruned.
# Starting Trial #16/50
# [I 2025-05-17 13:55:44,489] Trial 15 pruned.
# Starting Trial #17/50
# [I 2025-05-17 13:56:02,411] Trial 16 pruned.
# Starting Trial #18/50
# [I 2025-05-17 13:56:23,152] Trial 17 pruned.
# Starting Trial #19/50
# [I 2025-05-17 13:56:40,042] Trial 18 pruned.
# Starting Trial #20/50
# [I 2025-05-17 13:56:54,584] Trial 19 pruned.
# Starting Trial #21/50
# [I 2025-05-17 13:57:06,772] Trial 20 pruned.
# Starting Trial #22/50
# [I 2025-05-17 13:58:55,199] Trial 21 finished with value: 0.8109331594213098 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.26154872981964217, 'optimizer': 'Adam', 'lr': 0.00048053835184899636, 'weight_decay': 2.697512194911529e-06, 'batch_size': 256}. Best is trial 21 with value: 0.8109331594213098.
# Starting Trial #23/50
# [I 2025-05-17 13:59:08,712] Trial 22 pruned.
# Starting Trial #24/50
# [I 2025-05-17 14:01:03,310] Trial 23 finished with value: 0.8089294748333211 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.27694064687629477, 'optimizer': 'Adam', 'lr': 0.00038118980235773986, 'weight_decay': 2.215657065375794e-06, 'batch_size': 256}. Best is trial 21 with value: 0.8109331594213098.
# Starting Trial #25/50
# [I 2025-05-17 14:01:15,036] Trial 24 pruned.
# Starting Trial #26/50
# [I 2025-05-17 14:03:15,426] Trial 25 finished with value: 0.811058141746253 and parameters: {'n_layers': 3, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.3604653745013643, 'optimizer': 'Adam', 'lr': 0.0007354240334650009, 'weight_decay': 3.8955867846201365e-06, 'batch_size': 256}. Best is trial 25 with value: 0.811058141746253.
# Starting Trial #27/50
# [I 2025-05-17 14:03:28,302] Trial 26 pruned.
# Starting Trial #28/50
# [I 2025-05-17 14:03:39,278] Trial 27 pruned.
# Starting Trial #29/50
# [I 2025-05-17 14:03:49,456] Trial 28 pruned.
# Starting Trial #30/50
# [I 2025-05-17 14:06:24,164] Trial 29 finished with value: 0.807237100032118 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.16146369753844242, 'optimizer': 'Adam', 'lr': 0.0002799882340274217, 'weight_decay': 1.576678178515293e-05, 'batch_size': 128}. Best is trial 25 with value: 0.811058141746253.
# [FOLD 2/5] Best hyperparameters:
#   - n_layers: 3
#   - hidden_size: 384
#   - activation: LeakyReLU
#   - dropout: 0.3604653745013643
#   - optimizer: Adam
#   - lr: 0.0007354240334650009
#   - weight_decay: 3.8955867846201365e-06
#   - batch_size: 256
#
# [FOLD 2/5] Training model with best hyperparameters...
# [I 2025-05-17 14:07:08,570] A new study created in memory with name: no-name-a1a610c1-a03e-4978-807e-24528d833126
# [FOLD 2/5] Results: F1=0.8130, AUC=0.8266
#
# [FOLD 3/5] Starting outer fold...
# [FOLD 3/5] Starting hyperparameter search with Optuna...
# Starting Trial #1/50
# [I 2025-05-17 14:14:03,386] Trial 0 finished with value: 0.8051477211953154 and parameters: {'n_layers': 2, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.29076803063442347, 'optimizer': 'AdamW', 'lr': 1.256956910548419e-05, 'weight_decay': 2.2415242303289444e-05, 'batch_size': 512}. Best is trial 0 with value: 0.8051477211953154.
# Starting Trial #2/50
# [I 2025-05-17 14:17:30,495] Trial 1 finished with value: 0.8106360916062688 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.21329679748607758, 'optimizer': 'Adam', 'lr': 8.926091899570605e-05, 'weight_decay': 1.5366884464870723e-05, 'batch_size': 256}. Best is trial 1 with value: 0.8106360916062688.
# Starting Trial #3/50
# [I 2025-05-17 14:24:30,078] Trial 2 finished with value: 0.8082205260767958 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.2391046219858272, 'optimizer': 'Adam', 'lr': 2.855005469673563e-05, 'weight_decay': 0.0005482776174951304, 'batch_size': 256}. Best is trial 1 with value: 0.8106360916062688.
# Starting Trial #4/50
# [I 2025-05-17 14:27:50,994] Trial 3 finished with value: 0.8098127881919605 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.3766358145743719, 'optimizer': 'Adam', 'lr': 0.00092173666730746, 'weight_decay': 0.00044789445298912424, 'batch_size': 256}. Best is trial 1 with value: 0.8106360916062688.
# Starting Trial #5/50
# [I 2025-05-17 14:29:56,950] Trial 4 finished with value: 0.8097719387567593 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.24786141773363818, 'optimizer': 'Adam', 'lr': 0.0001615461236018039, 'weight_decay': 3.5476361054084576e-05, 'batch_size': 256}. Best is trial 1 with value: 0.8106360916062688.
# Starting Trial #6/50
# [I 2025-05-17 14:33:11,705] Trial 5 finished with value: 0.8111214890538937 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.12729736422467128, 'optimizer': 'Adam', 'lr': 0.00017299035521994356, 'weight_decay': 0.00026291727468840125, 'batch_size': 256}. Best is trial 5 with value: 0.8111214890538937.
# Starting Trial #7/50
# [I 2025-05-17 14:35:04,781] Trial 6 finished with value: 0.8060674909590292 and parameters: {'n_layers': 2, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.20735243394605823, 'optimizer': 'AdamW', 'lr': 0.0003020651502992475, 'weight_decay': 0.00037431507413299625, 'batch_size': 256}. Best is trial 5 with value: 0.8111214890538937.
# Starting Trial #8/50
# [I 2025-05-17 14:35:16,756] Trial 7 pruned.
# Starting Trial #9/50
# [I 2025-05-17 14:35:26,356] Trial 8 pruned.
# Starting Trial #10/50
# [I 2025-05-17 14:37:08,068] Trial 9 finished with value: 0.810383075183352 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.3215882625989481, 'optimizer': 'AdamW', 'lr': 0.0007953709192291828, 'weight_decay': 0.0008843869855729043, 'batch_size': 512}. Best is trial 5 with value: 0.8111214890538937.
# Starting Trial #11/50
# [I 2025-05-17 14:41:24,614] Trial 10 finished with value: 0.8116144221103451 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.10654222030198607, 'optimizer': 'Adam', 'lr': 9.903644499204665e-05, 'weight_decay': 9.599447300527833e-05, 'batch_size': 128}. Best is trial 10 with value: 0.8116144221103451.
# Starting Trial #12/50
# [I 2025-05-17 14:45:36,304] Trial 11 finished with value: 0.8058596263529907 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.12162978541036734, 'optimizer': 'Adam', 'lr': 0.000111500705952647, 'weight_decay': 8.085802027858723e-05, 'batch_size': 128}. Best is trial 10 with value: 0.8116144221103451.
# Starting Trial #13/50
# [I 2025-05-17 14:48:52,348] Trial 12 finished with value: 0.807378012433599 and parameters: {'n_layers': 5, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.10327932091050061, 'optimizer': 'Adam', 'lr': 0.00028066535181424, 'weight_decay': 0.00011301216385141503, 'batch_size': 128}. Best is trial 10 with value: 0.8116144221103451.
# Starting Trial #14/50
# [I 2025-05-17 14:49:13,864] Trial 13 pruned.
# Starting Trial #15/50
# [I 2025-05-17 14:49:37,973] Trial 14 pruned.
# Starting Trial #16/50
# [I 2025-05-17 14:49:59,810] Trial 15 pruned.
# Starting Trial #17/50
# [I 2025-05-17 14:53:48,925] Trial 16 finished with value: 0.8100288622513845 and parameters: {'n_layers': 2, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.15288136405277897, 'optimizer': 'Adam', 'lr': 0.00015263719581115425, 'weight_decay': 0.00021336930114250013, 'batch_size': 128}. Best is trial 10 with value: 0.8116144221103451.
# Starting Trial #18/50
# [I 2025-05-17 14:56:50,092] Trial 17 finished with value: 0.8065215212245151 and parameters: {'n_layers': 5, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.1400685214604165, 'optimizer': 'Adam', 'lr': 0.00047803645062039076, 'weight_decay': 1.4928095540636309e-06, 'batch_size': 128}. Best is trial 10 with value: 0.8116144221103451.
# Starting Trial #19/50
# [I 2025-05-17 14:57:04,268] Trial 18 pruned.
# Starting Trial #20/50
# [I 2025-05-17 14:57:15,822] Trial 19 pruned.
# Starting Trial #21/50
# [I 2025-05-17 14:57:29,627] Trial 20 pruned.
# Starting Trial #22/50
# [I 2025-05-17 14:57:43,417] Trial 21 pruned.
# Starting Trial #23/50
# [I 2025-05-17 14:58:05,408] Trial 22 pruned.
# Starting Trial #24/50
# [I 2025-05-17 14:58:17,472] Trial 23 pruned.
# Starting Trial #25/50
# [I 2025-05-17 14:58:32,226] Trial 24 pruned.
# Starting Trial #26/50
# [I 2025-05-17 14:58:52,876] Trial 25 pruned.
# Starting Trial #27/50
# [I 2025-05-17 14:59:07,362] Trial 26 pruned.
# Starting Trial #28/50
# [I 2025-05-17 14:59:23,307] Trial 27 pruned.
# Starting Trial #29/50
# [I 2025-05-17 14:59:32,861] Trial 28 pruned.
# Starting Trial #30/50
# [I 2025-05-17 15:02:23,307] Trial 29 finished with value: 0.8085072968402596 and parameters: {'n_layers': 2, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.1488366284589697, 'optimizer': 'AdamW', 'lr': 0.00021240668945863612, 'weight_decay': 1.3420909639124838e-05, 'batch_size': 128}. Best is trial 10 with value: 0.8116144221103451.
# [FOLD 3/5] Best hyperparameters:
#   - n_layers: 5
#   - hidden_size: 384
#   - activation: LeakyReLU
#   - dropout: 0.10654222030198607
#   - optimizer: Adam
#   - lr: 9.903644499204665e-05
#   - weight_decay: 9.599447300527833e-05
#   - batch_size: 128
#
# [FOLD 3/5] Training model with best hyperparameters...
# [I 2025-05-17 15:03:58,137] A new study created in memory with name: no-name-605f4cc8-cad2-4053-8975-37df3debd677
# [FOLD 3/5] Results: F1=0.8128, AUC=0.8216
#
# [FOLD 4/5] Starting outer fold...
# [FOLD 4/5] Starting hyperparameter search with Optuna...
# Starting Trial #1/50
# [I 2025-05-17 15:07:49,992] Trial 0 finished with value: 0.8098812187639886 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.30533975991279705, 'optimizer': 'Adam', 'lr': 4.826850936550912e-05, 'weight_decay': 4.6180267797595915e-05, 'batch_size': 512}. Best is trial 0 with value: 0.8098812187639886.
# Starting Trial #2/50
# [I 2025-05-17 15:13:39,645] Trial 1 finished with value: 0.8081510311705382 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.32344916458702966, 'optimizer': 'AdamW', 'lr': 4.4843052216160775e-05, 'weight_decay': 1.3804871660132023e-06, 'batch_size': 128}. Best is trial 0 with value: 0.8098812187639886.
# Starting Trial #3/50
# [I 2025-05-17 15:16:41,807] Trial 2 finished with value: 0.8099092849047386 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.31692250546095413, 'optimizer': 'Adam', 'lr': 0.00032389902487257107, 'weight_decay': 2.4132487685782464e-06, 'batch_size': 128}. Best is trial 2 with value: 0.8099092849047386.
# Starting Trial #4/50
# [I 2025-05-17 15:21:48,348] Trial 3 finished with value: 0.8093135474498266 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.3742614461354774, 'optimizer': 'Adam', 'lr': 7.437851745526593e-05, 'weight_decay': 1.9921790561039424e-06, 'batch_size': 128}. Best is trial 2 with value: 0.8099092849047386.
# Starting Trial #5/50
# [I 2025-05-17 15:24:29,660] Trial 4 finished with value: 0.808186586536552 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.2306772109074925, 'optimizer': 'Adam', 'lr': 0.0005861717308985924, 'weight_decay': 1.939054229350836e-06, 'batch_size': 128}. Best is trial 2 with value: 0.8099092849047386.
# Starting Trial #6/50
# [I 2025-05-17 15:27:15,592] Trial 5 finished with value: 0.807644429333548 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.1715666068901829, 'optimizer': 'AdamW', 'lr': 0.0005074662586774627, 'weight_decay': 6.394809546134582e-05, 'batch_size': 128}. Best is trial 2 with value: 0.8099092849047386.
# Starting Trial #7/50
# [I 2025-05-17 15:29:02,637] Trial 6 finished with value: 0.8036429668035322 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.15512211871777512, 'optimizer': 'AdamW', 'lr': 0.00017698010208011132, 'weight_decay': 1.2797555079608306e-05, 'batch_size': 512}. Best is trial 2 with value: 0.8099092849047386.
# Starting Trial #8/50
# [I 2025-05-17 15:29:12,668] Trial 7 pruned.
# Starting Trial #9/50
# [I 2025-05-17 15:29:31,437] Trial 8 pruned.
# Starting Trial #10/50
# [I 2025-05-17 15:29:42,005] Trial 9 pruned.
# Starting Trial #11/50
# [I 2025-05-17 15:32:51,036] Trial 10 finished with value: 0.8101633893422534 and parameters: {'n_layers': 5, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.39924026077588837, 'optimizer': 'Adam', 'lr': 0.0002659648764358807, 'weight_decay': 0.0007964388966320784, 'batch_size': 256}. Best is trial 10 with value: 0.8101633893422534.
# Starting Trial #12/50
# [I 2025-05-17 15:36:47,938] Trial 11 finished with value: 0.8084112859873017 and parameters: {'n_layers': 5, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.3977192275878661, 'optimizer': 'Adam', 'lr': 0.00020930556031336297, 'weight_decay': 0.0007874620426092251, 'batch_size': 256}. Best is trial 10 with value: 0.8101633893422534.
# Starting Trial #13/50
# [I 2025-05-17 15:39:49,771] Trial 12 finished with value: 0.808742827060931 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.30382833456233205, 'optimizer': 'Adam', 'lr': 0.0002706289407470231, 'weight_decay': 0.0008662388867703845, 'batch_size': 256}. Best is trial 10 with value: 0.8101633893422534.
# Starting Trial #14/50
# [I 2025-05-17 15:42:11,648] Trial 13 finished with value: 0.8093317387921409 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.3527184940118233, 'optimizer': 'Adam', 'lr': 0.0008985716850657885, 'weight_decay': 1.1323023537301692e-05, 'batch_size': 256}. Best is trial 10 with value: 0.8101633893422534.
# Starting Trial #15/50
# [I 2025-05-17 15:45:16,293] Trial 14 finished with value: 0.8097906863549124 and parameters: {'n_layers': 5, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.27403155735284246, 'optimizer': 'Adam', 'lr': 0.00033998432879148085, 'weight_decay': 0.0002839238988599722, 'batch_size': 256}. Best is trial 10 with value: 0.8101633893422534.
# Starting Trial #16/50
# [I 2025-05-17 15:45:39,114] Trial 15 pruned.
# Starting Trial #17/50
# [I 2025-05-17 15:46:00,147] Trial 16 pruned.
# Starting Trial #18/50
# [I 2025-05-17 15:48:35,534] Trial 17 finished with value: 0.8080318479138398 and parameters: {'n_layers': 5, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.3994033611952641, 'optimizer': 'Adam', 'lr': 0.000417619622884283, 'weight_decay': 2.2676190090850464e-05, 'batch_size': 256}. Best is trial 10 with value: 0.8101633893422534.
# Starting Trial #19/50
# [I 2025-05-17 15:50:31,571] Trial 18 finished with value: 0.8079920307600248 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.27919633147243916, 'optimizer': 'Adam', 'lr': 0.0009430087343931038, 'weight_decay': 5.068132661938653e-06, 'batch_size': 256}. Best is trial 10 with value: 0.8101633893422534.
# Starting Trial #20/50
# [I 2025-05-17 15:55:34,701] Trial 19 finished with value: 0.809210304339094 and parameters: {'n_layers': 2, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.3474920299586132, 'optimizer': 'Adam', 'lr': 0.00017992488613736396, 'weight_decay': 0.00033619775952951274, 'batch_size': 128}. Best is trial 10 with value: 0.8101633893422534.
# Starting Trial #21/50
# [I 2025-05-17 15:55:49,228] Trial 20 pruned.
# Starting Trial #22/50
# [I 2025-05-17 15:55:59,842] Trial 21 pruned.
# Starting Trial #23/50
# [I 2025-05-17 15:56:10,495] Trial 22 pruned.
# Starting Trial #24/50
# [I 2025-05-17 15:56:21,150] Trial 23 pruned.
# Starting Trial #25/50
# [I 2025-05-17 15:58:12,039] Trial 24 finished with value: 0.8117984001355861 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.24109254914694012, 'optimizer': 'Adam', 'lr': 0.00029061003691572987, 'weight_decay': 1.0375415839142268e-06, 'batch_size': 512}. Best is trial 24 with value: 0.8117984001355861.
# Starting Trial #26/50
# [I 2025-05-17 16:01:11,200] Trial 25 finished with value: 0.8051451841466989 and parameters: {'n_layers': 4, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.21167064404228894, 'optimizer': 'Adam', 'lr': 0.00027309469227371897, 'weight_decay': 1.241023431660684e-06, 'batch_size': 128}. Best is trial 24 with value: 0.8117984001355861.
# Starting Trial #27/50
# [I 2025-05-17 16:03:09,770] Trial 26 finished with value: 0.8027619087720135 and parameters: {'n_layers': 5, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.2456974069165546, 'optimizer': 'AdamW', 'lr': 0.0005772599508404873, 'weight_decay': 1.0778925118422003e-06, 'batch_size': 512}. Best is trial 24 with value: 0.8117984001355861.
# Starting Trial #28/50
# [I 2025-05-17 16:05:35,193] Trial 27 finished with value: 0.8082454347737817 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'LeakyReLU', 'dropout': 0.20298284303372452, 'optimizer': 'Adam', 'lr': 0.0002990231194880619, 'weight_decay': 4.19596630339761e-06, 'batch_size': 256}. Best is trial 24 with value: 0.8117984001355861.
# Starting Trial #29/50
# [I 2025-05-17 16:09:00,158] Trial 28 finished with value: 0.8083838112806586 and parameters: {'n_layers': 4, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.28201569408138566, 'optimizer': 'Adam', 'lr': 0.00018204282298432196, 'weight_decay': 2.6727149754055234e-06, 'batch_size': 128}. Best is trial 24 with value: 0.8117984001355861.
# Starting Trial #30/50
# [I 2025-05-17 16:09:11,552] Trial 29 pruned.
# [FOLD 4/5] Best hyperparameters:
#   - n_layers: 4
#   - hidden_size: 512
#   - activation: LeakyReLU
#   - dropout: 0.24109254914694012
#   - optimizer: Adam
#   - lr: 0.00029061003691572987
#   - weight_decay: 1.0375415839142268e-06
#   - batch_size: 512
#
# [FOLD 4/5] Training model with best hyperparameters...
# [I 2025-05-17 16:09:48,302] A new study created in memory with name: no-name-c63a24bb-d86c-4234-b5fc-e800d2226a50
# [FOLD 4/5] Results: F1=0.8115, AUC=0.8240
#
# [FOLD 5/5] Starting outer fold...
# [FOLD 5/5] Starting hyperparameter search with Optuna...
# Starting Trial #1/50
# [I 2025-05-17 16:12:37,177] Trial 0 finished with value: 0.8119630782369324 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.24365316451405566, 'optimizer': 'AdamW', 'lr': 0.0003417571108227952, 'weight_decay': 3.0772798073446974e-06, 'batch_size': 128}. Best is trial 0 with value: 0.8119630782369324.
# Starting Trial #2/50
# [I 2025-05-17 16:19:25,746] Trial 1 finished with value: 0.8070973839522404 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'LeakyReLU', 'dropout': 0.3190330796026256, 'optimizer': 'AdamW', 'lr': 3.175502679984937e-05, 'weight_decay': 0.00011285669321126579, 'batch_size': 256}. Best is trial 0 with value: 0.8119630782369324.
# Starting Trial #3/50
# [I 2025-05-17 16:22:27,998] Trial 2 finished with value: 0.8070207790858585 and parameters: {'n_layers': 5, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.2049563057504377, 'optimizer': 'Adam', 'lr': 0.0007642434258164472, 'weight_decay': 1.7755895547702147e-06, 'batch_size': 128}. Best is trial 0 with value: 0.8119630782369324.
# Starting Trial #4/50
# [I 2025-05-17 16:31:58,114] Trial 3 finished with value: 0.8082620204374193 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.31452012750646774, 'optimizer': 'Adam', 'lr': 2.2609106988283192e-05, 'weight_decay': 2.2554025245325854e-06, 'batch_size': 512}. Best is trial 0 with value: 0.8119630782369324.
# Starting Trial #5/50
# [I 2025-05-17 16:35:58,373] Trial 4 finished with value: 0.8102891223450731 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.15505574854387386, 'optimizer': 'Adam', 'lr': 4.221926636091116e-05, 'weight_decay': 1.0835091590071066e-06, 'batch_size': 256}. Best is trial 0 with value: 0.8119630782369324.
# Starting Trial #6/50
# [I 2025-05-17 16:38:50,020] Trial 5 finished with value: 0.8103389587712325 and parameters: {'n_layers': 3, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.37633411490623736, 'optimizer': 'Adam', 'lr': 0.0001922161328667228, 'weight_decay': 5.3734308512292384e-05, 'batch_size': 256}. Best is trial 0 with value: 0.8119630782369324.
# Starting Trial #7/50
# [I 2025-05-17 16:39:16,085] Trial 6 pruned.
# Starting Trial #8/50
# [I 2025-05-17 16:39:41,122] Trial 7 pruned.
# Starting Trial #9/50
# [I 2025-05-17 16:42:51,439] Trial 8 finished with value: 0.808927225636982 and parameters: {'n_layers': 2, 'hidden_size': 384, 'activation': 'LeakyReLU', 'dropout': 0.36604545294226787, 'optimizer': 'AdamW', 'lr': 0.00034916727349921866, 'weight_decay': 1.6657709031037506e-05, 'batch_size': 128}. Best is trial 0 with value: 0.8119630782369324.
# Starting Trial #10/50
# [I 2025-05-17 16:43:07,428] Trial 9 pruned.
# Starting Trial #11/50
# [I 2025-05-17 16:46:04,749] Trial 10 finished with value: 0.8127713018367481 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.2432505652603768, 'optimizer': 'AdamW', 'lr': 0.0008796657507085534, 'weight_decay': 1.1409996016550075e-05, 'batch_size': 128}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #12/50
# [I 2025-05-17 16:48:59,493] Trial 11 finished with value: 0.8077868183542085 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.24892138135068217, 'optimizer': 'AdamW', 'lr': 0.0008309841862455731, 'weight_decay': 0.0009226278566115324, 'batch_size': 128}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #13/50
# [I 2025-05-17 16:49:24,960] Trial 12 pruned.
# Starting Trial #14/50
# [I 2025-05-17 16:52:16,790] Trial 13 finished with value: 0.8095665704587076 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.21023134095576756, 'optimizer': 'AdamW', 'lr': 0.00039480466364522955, 'weight_decay': 6.753106696904439e-06, 'batch_size': 128}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #15/50
# [I 2025-05-17 16:54:06,430] Trial 14 finished with value: 0.8080192700649937 and parameters: {'n_layers': 4, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.2771284218293727, 'optimizer': 'AdamW', 'lr': 0.0009816883798742138, 'weight_decay': 3.331541166620747e-05, 'batch_size': 512}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #16/50
# [I 2025-05-17 16:54:26,987] Trial 15 pruned.
# Starting Trial #17/50
# [I 2025-05-17 16:57:40,857] Trial 16 finished with value: 0.8086004240838971 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.10047265399885608, 'optimizer': 'AdamW', 'lr': 0.00021533232340590193, 'weight_decay': 1.5519230366008528e-05, 'batch_size': 128}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #18/50
# [I 2025-05-17 17:00:46,359] Trial 17 finished with value: 0.8077807838526362 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.2776440270464846, 'optimizer': 'AdamW', 'lr': 0.0005016302311220392, 'weight_decay': 4.403892306801984e-06, 'batch_size': 128}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #19/50
# [I 2025-05-17 17:00:58,457] Trial 18 pruned.
# Starting Trial #20/50
# [I 2025-05-17 17:03:18,783] Trial 19 finished with value: 0.8091253251145765 and parameters: {'n_layers': 3, 'hidden_size': 512, 'activation': 'ReLU', 'dropout': 0.33560706689577263, 'optimizer': 'AdamW', 'lr': 0.00046076050720502234, 'weight_decay': 2.4915562531702248e-05, 'batch_size': 256}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #21/50
# [I 2025-05-17 17:06:20,793] Trial 20 finished with value: 0.8108569782455687 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.27612912090245195, 'optimizer': 'AdamW', 'lr': 0.0006156965370019278, 'weight_decay': 8.92367038469074e-06, 'batch_size': 128}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #22/50
# [I 2025-05-17 17:06:40,233] Trial 21 pruned.
# Starting Trial #23/50
# [I 2025-05-17 17:10:08,880] Trial 22 finished with value: 0.8079006108579477 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.2281383080540394, 'optimizer': 'AdamW', 'lr': 0.0002553186613261417, 'weight_decay': 3.1742508574057675e-06, 'batch_size': 128}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #24/50
# [I 2025-05-17 17:13:07,671] Trial 23 finished with value: 0.8084145882236359 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.2831355747883741, 'optimizer': 'AdamW', 'lr': 0.000647629536523285, 'weight_decay': 8.590169085008135e-06, 'batch_size': 128}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #25/50
# [I 2025-05-17 17:13:26,992] Trial 24 pruned.
# Starting Trial #26/50
# [I 2025-05-17 17:16:50,452] Trial 25 finished with value: 0.8082733542522412 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.34960273883880794, 'optimizer': 'AdamW', 'lr': 0.000299202257683252, 'weight_decay': 1.5495112627685546e-05, 'batch_size': 128}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #27/50
# [I 2025-05-17 17:20:35,250] Trial 26 finished with value: 0.8107026510928518 and parameters: {'n_layers': 3, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.3972417542600286, 'optimizer': 'Adam', 'lr': 0.0006077837080598061, 'weight_decay': 6.091672620757222e-06, 'batch_size': 128}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #28/50
# [I 2025-05-17 17:23:24,027] Trial 27 finished with value: 0.8116377496407003 and parameters: {'n_layers': 2, 'hidden_size': 256, 'activation': 'ReLU', 'dropout': 0.22881284720745437, 'optimizer': 'AdamW', 'lr': 0.0009809096174906425, 'weight_decay': 1.00024156460035e-06, 'batch_size': 128}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #29/50
# [I 2025-05-17 17:25:28,971] Trial 28 finished with value: 0.8068647638703993 and parameters: {'n_layers': 3, 'hidden_size': 384, 'activation': 'ReLU', 'dropout': 0.22154716845675543, 'optimizer': 'AdamW', 'lr': 0.0009157551491133393, 'weight_decay': 1.0508745288062493e-06, 'batch_size': 256}. Best is trial 10 with value: 0.8127713018367481.
# Starting Trial #30/50
# [I 2025-05-17 17:25:40,676] Trial 29 pruned.
# [FOLD 5/5] Best hyperparameters:
#   - n_layers: 2
#   - hidden_size: 256
#   - activation: ReLU
#   - dropout: 0.2432505652603768
#   - optimizer: AdamW
#   - lr: 0.0008796657507085534
#   - weight_decay: 1.1409996016550075e-05
#   - batch_size: 128
#
# [FOLD 5/5] Training model with best hyperparameters...
#
# [FOLD 5/5] Results: F1=0.8095, AUC=0.8217
#
# ================================================================================
#  NESTED CV COMPLETED
# ================================================================================
#
# [RESULTS] Nested CV Results:
#   - Avg F1=0.8119 (±0.0013)
#   - Avg AUC=0.8247 (±0.0030)
#
# [DETAILED FOLD RESULTS]
#   Fold 1: F1=0.8129, AUC=0.8294
#   Fold 2: F1=0.8130, AUC=0.8266
#   Fold 3: F1=0.8128, AUC=0.8216
#   Fold 4: F1=0.8115, AUC=0.8240
#   Fold 5: F1=0.8095, AUC=0.8217
#
# ================================================================================
#  DETERMINING BEST HYPERPARAMETERS FROM TOP-PERFORMING FOLD
# ================================================================================
#
# [BEST FOLD] Fold 2 with F1=0.8130, AUC=0.8266
#
# [FINAL HYPERPARAMETERS]
#   - n_layers: 3
#   - hidden_size: 384
#   - activation: LeakyReLU
#   - dropout: 0.360465
#   - optimizer: Adam
#   - lr: 0.000735
#   - weight_decay: 0.000004
#   - batch_size: 256
#
# ================================================================================
#  TRAINING FINAL MODEL WITH VALIDATION METRICS TRACKING
# ================================================================================
#
# [TRACKING] Training final model with metrics tracking...
# Epoch 1/100 - Train Loss: 0.5470, Val Loss: 0.5251, Train F1: 0.7919, Val F1: 0.7932
# Epoch 2/100 - Train Loss: 0.5190, Val Loss: 0.5143, Train F1: 0.8032, Val F1: 0.8054
# Epoch 3/100 - Train Loss: 0.5098, Val Loss: 0.5097, Train F1: 0.8067, Val F1: 0.8024
# Epoch 4/100 - Train Loss: 0.5029, Val Loss: 0.5041, Train F1: 0.8104, Val F1: 0.8101
# Epoch 5/100 - Train Loss: 0.4985, Val Loss: 0.5032, Train F1: 0.8129, Val F1: 0.8077
# Epoch 6/100 - Train Loss: 0.4934, Val Loss: 0.5047, Train F1: 0.8146, Val F1: 0.8090
# Epoch 7/100 - Train Loss: 0.4894, Val Loss: 0.5026, Train F1: 0.8172, Val F1: 0.8073
# Epoch 8/100 - Train Loss: 0.4849, Val Loss: 0.4994, Train F1: 0.8185, Val F1: 0.8142
# Epoch 9/100 - Train Loss: 0.4813, Val Loss: 0.4985, Train F1: 0.8204, Val F1: 0.8153
# Epoch 10/100 - Train Loss: 0.4769, Val Loss: 0.4992, Train F1: 0.8220, Val F1: 0.8112
# Epoch 11/100 - Train Loss: 0.4740, Val Loss: 0.5004, Train F1: 0.8234, Val F1: 0.8022
# Epoch 12/100 - Train Loss: 0.4723, Val Loss: 0.4990, Train F1: 0.8250, Val F1: 0.8089
# Epoch 13/100 - Train Loss: 0.4590, Val Loss: 0.4989, Train F1: 0.8303, Val F1: 0.8056
# Epoch 14/100 - Train Loss: 0.4537, Val Loss: 0.5004, Train F1: 0.8332, Val F1: 0.8129
# Epoch 15/100 - Train Loss: 0.4523, Val Loss: 0.5013, Train F1: 0.8333, Val F1: 0.8125
# Epoch 16/100 - Train Loss: 0.4419, Val Loss: 0.5016, Train F1: 0.8384, Val F1: 0.8090
# Epoch 17/100 - Train Loss: 0.4386, Val Loss: 0.5009, Train F1: 0.8390, Val F1: 0.8127
# Epoch 18/100 - Train Loss: 0.4366, Val Loss: 0.5011, Train F1: 0.8402, Val F1: 0.8086
# Epoch 19/100 - Train Loss: 0.4305, Val Loss: 0.5083, Train F1: 0.8429, Val F1: 0.8047
# Early stopping triggered! No significant improvement for 10 epochs.
# Best epoch was 9 with validation loss: 0.498547
# [RESULTS] Best validation loss: 0.4985, F1: 0.8153 at epoch 9
#
# [METRICS] At best epoch 9:
#   - Training Loss: 0.4813
#   - Validation Loss: 0.4985
#   - Training F1: 0.8204
#   - Validation F1: 0.8153
# [CONCLUSION] Based on the validation F1 score curves, the optimal number of epochs
#              for training the final model is: 9

# %%
# STEP 4: EVALUATE ON TEST SET
print("\n" + "="*80)
print(" EVALUATING FINAL MODEL ON TEST SET")
print("="*80)

# Create test data loader
test_loader = DataLoader(
    TensorDataset(X_test, y_test),
    batch_size=final_params['batch_size'],
    shuffle=False,
    **loader_kwargs
)

# Evaluate on test set
final_model.eval()
test_preds = []
test_labels = []

with torch.no_grad():
    for xb, yb in test_loader:
        xb, yb = xb.to(device), yb.to(device)
        outputs = final_model(xb)

        test_preds.append(torch.sigmoid(outputs).cpu())
        test_labels.append(yb.cpu())

# Calculate and report metrics
test_preds_cat = torch.cat(test_preds).numpy()
test_labels_cat = torch.cat(test_labels).numpy()
test_preds_bin = (test_preds_cat > 0.5).astype(int)

# Calculate metrics
test_f1 = f1_score(test_labels_cat, test_preds_bin)
test_precision = precision_score(test_labels_cat, test_preds_bin)
test_recall = recall_score(test_labels_cat, test_preds_bin)
test_auc = roc_auc_score(test_labels_cat, test_preds_cat)

# Print results
print("\n[TEST RESULTS]")
print(f"  - F1 Score: {test_f1:.4f}")
print(f"  - Precision: {test_precision:.4f}")
print(f"  - Recall: {test_recall:.4f}")
print(f"  - AUC: {test_auc:.4f}")

# Confusion Matrix
cm = confusion_matrix(test_labels_cat, test_preds_bin)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix on Test Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(test_labels_cat, test_preds_cat)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {test_auc:.4f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve on Test Set')
plt.legend()
plt.grid(True)
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(test_labels_cat, test_preds_cat)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve on Test Set')
plt.grid(True)
plt.show()
# Out:
# ================================================================================
#  EVALUATING FINAL MODEL ON TEST SET
# ================================================================================
#
# [TEST RESULTS]
#   - F1 Score: 0.8212
#   - Precision: 0.7658
#   - Recall: 0.8851
#   - AUC: 0.8272
